# %%
# ДЗ по "Сбор и разметка данных (семинары)"

## Семинар 9. Инструменты разметки наборов данных

###  Домашнее задание:

# %%
# Устанавливаем пакеты
# !pip install pandas
# !pip install nltk
# !pip install scikit-learn
# !pip install label-studio
# !pip install matplotlib
# !pip install wget
# Out:
# Collecting pandas
#   Obtaining dependency information for pandas from https://files.pythonhosted.org/packages/c3/6c/ea362eef61f05553aaf1a24b3e96b2d0603f5dc71a3bd35688a24ed88843/pandas-2.0.3-cp38-cp38-win_amd64.whl.metadata
#   Downloading pandas-2.0.3-cp38-cp38-win_amd64.whl.metadata (18 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in f:\data-collection-and-markup_9\pythonproject\.venv\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in f:\data-collection-and-markup_9\pythonproject\.venv\lib\site-packages (from pandas) (2024.2)
# Collecting tzdata>=2022.1 (from pandas)
#   Obtaining dependency information for tzdata>=2022.1 from https://files.pythonhosted.org/packages/a6/ab/7e5f53c3b9d14972843a647d8d7a853969a58aecc7559cb3267302c94774/tzdata-2024.2-py2.py3-none-any.whl.metadata
#   Downloading tzdata-2024.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting numpy>=1.20.3 (from pandas)
#   Obtaining dependency information for numpy>=1.20.3 from https://files.pythonhosted.org/packages/69/65/0d47953afa0ad569d12de5f65d964321c208492064c38fe3b0b9744f8d44/numpy-1.24.4-cp38-cp38-win_amd64.whl.metadata
#   Downloading numpy-1.24.4-cp38-cp38-win_amd64.whl.metadata (5.6 kB)
# Requirement already satisfied: six>=1.5 in f:\data-collection-and-markup_9\pythonproject\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Downloading pandas-2.0.3-cp38-cp38-win_amd64.whl (10.8 MB)
#    ---------------------------------------- 0.0/10.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/10.8 MB 1.9 MB/s eta 0:00:06
#     --------------------------------------- 0.2/10.8 MB 1.8 MB/s eta 0:00:06
#    - -------------------------------------- 0.3/10.8 MB 2.1 MB/s eta 0:00:05
#    - -------------------------------------- 0.4/10.8 MB 2.3 MB/s eta 0:00:05
#    -- ------------------------------------- 0.7/10.8 MB 3.3 MB/s eta 0:00:04
#    ---- ----------------------------------- 1.3/10.8 MB 4.0 MB/s eta 0:00:03
#    -------- ------------------------------- 2.2/10.8 MB 5.5 MB/s eta 0:00:02
#    ---------- ----------------------------- 2.7/10.8 MB 6.2 MB/s eta 0:00:02
#    ------------ --------------------------- 3.4/10.8 MB 6.8 MB/s eta 0:00:02
#    --------------- ------------------------ 4.1/10.8 MB 7.1 MB/s eta 0:00:01
#    ------------------ --------------------- 4.9/10.8 MB 7.6 MB/s eta 0:00:01
#    -------------------- ------------------- 5.5/10.8 MB 7.9 MB/s eta 0:00:01
#    ----------------------- ---------------- 6.5/10.8 MB 8.2 MB/s eta 0:00:01
#    --------------------------- ------------ 7.4/10.8 MB 8.8 MB/s eta 0:00:01
#    ------------------------------ --------- 8.2/10.8 MB 8.9 MB/s eta 0:00:01
#    -------------------------------- ------- 8.7/10.8 MB 8.7 MB/s eta 0:00:01
#    ----------------------------------- ---- 9.6/10.8 MB 8.7 MB/s eta 0:00:01
#    ------------------------------------- -- 10.1/10.8 MB 8.6 MB/s eta 0:00:01
#    ---------------------------------------  10.8/10.8 MB 9.8 MB/s eta 0:00:01
#    ---------------------------------------  10.8/10.8 MB 9.8 MB/s eta 0:00:01
#    ---------------------------------------  10.8/10.8 MB 9.8 MB/s eta 0:00:01
#    ---------------------------------------- 10.8/10.8 MB 8.3 MB/s eta 0:00:00
# Downloading numpy-1.24.4-cp38-cp38-win_amd64.whl (14.9 MB)
#    ---------------------------------------- 0.0/14.9 MB ? eta -:--:--
#    - -------------------------------------- 0.7/14.9 MB 14.8 MB/s eta 0:00:01
#    --- ------------------------------------ 1.4/14.9 MB 13.0 MB/s eta 0:00:02
#    ----- ---------------------------------- 2.1/14.9 MB 12.2 MB/s eta 0:00:02
#    ------- -------------------------------- 2.8/14.9 MB 11.8 MB/s eta 0:00:02
#    --------- ------------------------------ 3.5/14.9 MB 12.4 MB/s eta 0:00:01
#    ----------- ---------------------------- 4.2/14.9 MB 11.7 MB/s eta 0:00:01
#    ------------- -------------------------- 5.1/14.9 MB 12.1 MB/s eta 0:00:01
#    --------------- ------------------------ 5.8/14.9 MB 11.6 MB/s eta 0:00:01
#    ------------------ --------------------- 6.7/14.9 MB 11.9 MB/s eta 0:00:01
#    -------------------- ------------------- 7.7/14.9 MB 11.4 MB/s eta 0:00:01
#    --------------------- ------------------ 8.1/14.9 MB 11.3 MB/s eta 0:00:01
#    ------------------------ --------------- 9.2/14.9 MB 11.3 MB/s eta 0:00:01
#    ------------------------- -------------- 9.6/14.9 MB 10.9 MB/s eta 0:00:01
#    --------------------------- ------------ 10.3/14.9 MB 10.9 MB/s eta 0:00:01
#    ------------------------------ --------- 11.2/14.9 MB 10.9 MB/s eta 0:00:01
#    ------------------------------- -------- 11.8/14.9 MB 10.7 MB/s eta 0:00:01
#    ---------------------------------- ----- 12.8/14.9 MB 10.9 MB/s eta 0:00:01
#    ------------------------------------ --- 13.5/14.9 MB 10.9 MB/s eta 0:00:01
#    -------------------------------------- - 14.4/14.9 MB 10.7 MB/s eta 0:00:01
#    ---------------------------------------  14.9/14.9 MB 10.9 MB/s eta 0:00:01
#    ---------------------------------------  14.9/14.9 MB 10.9 MB/s eta 0:00:01
#    ---------------------------------------  14.9/14.9 MB 10.9 MB/s eta 0:00:01
#    ---------------------------------------- 14.9/14.9 MB 9.0 MB/s eta 0:00:00
# Downloading tzdata-2024.2-py2.py3-none-any.whl (346 kB)
#    ---------------------------------------- 0.0/346.6 kB ? eta -:--:--
#    ---------------------------------------- 346.6/346.6 kB 7.2 MB/s eta 0:00:00
# Installing collected packages: tzdata, numpy, pandas
# Successfully installed numpy-1.24.4 pandas-2.0.3 tzdata-2024.2
# [notice] A new release of pip is available: 23.2.1 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Collecting nltk
#   Obtaining dependency information for nltk from https://files.pythonhosted.org/packages/4d/66/7d9e26593edda06e8cb531874633f7c2372279c3b0f46235539fe546df8b/nltk-3.9.1-py3-none-any.whl.metadata
#   Using cached nltk-3.9.1-py3-none-any.whl.metadata (2.9 kB)
# Collecting click (from nltk)
#   Obtaining dependency information for click from https://files.pythonhosted.org/packages/00/2e/d53fa4befbf2cfa713304affc7ca780ce4fc1fd8710527771b58311a3229/click-8.1.7-py3-none-any.whl.metadata
#   Downloading click-8.1.7-py3-none-any.whl.metadata (3.0 kB)
# Collecting joblib (from nltk)
#   Obtaining dependency information for joblib from https://files.pythonhosted.org/packages/91/29/df4b9b42f2be0b623cbd5e2140cafcaa2bef0759a00b7b70104dcfe2fb51/joblib-1.4.2-py3-none-any.whl.metadata
#   Downloading joblib-1.4.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting regex>=2021.8.3 (from nltk)
#   Obtaining dependency information for regex>=2021.8.3 from https://files.pythonhosted.org/packages/33/fc/07e14d7727a9f5773abb728f18f3497ea917c76f16155a68594460d86b8b/regex-2024.9.11-cp38-cp38-win_amd64.whl.metadata
#   Downloading regex-2024.9.11-cp38-cp38-win_amd64.whl.metadata (41 kB)
#      ---------------------------------------- 0.0/41.5 kB ? eta -:--:--
#      ---------------------------------------- 41.5/41.5 kB 2.1 MB/s eta 0:00:00
# Collecting tqdm (from nltk)
#   Obtaining dependency information for tqdm from https://files.pythonhosted.org/packages/48/5d/acf5905c36149bbaec41ccf7f2b68814647347b72075ac0b1fe3022fdc73/tqdm-4.66.5-py3-none-any.whl.metadata
#   Downloading tqdm-4.66.5-py3-none-any.whl.metadata (57 kB)
#      ---------------------------------------- 0.0/57.6 kB ? eta -:--:--
#      ---------------------------------------- 57.6/57.6 kB 3.2 MB/s eta 0:00:00
# Requirement already satisfied: colorama in f:\data-collection-and-markup_9\pythonproject\.venv\lib\site-packages (from click->nltk) (0.4.6)
# Using cached nltk-3.9.1-py3-none-any.whl (1.5 MB)
# Downloading regex-2024.9.11-cp38-cp38-win_amd64.whl (274 kB)
#    ---------------------------------------- 0.0/274.1 kB ? eta -:--:--
#    -------------------------------------- - 266.2/274.1 kB 3.3 MB/s eta 0:00:01
#    ---------------------------------------- 274.1/274.1 kB 2.1 MB/s eta 0:00:00
# Downloading click-8.1.7-py3-none-any.whl (97 kB)
#    ---------------------------------------- 0.0/97.9 kB ? eta -:--:--
#    ------------------------------------- -- 92.2/97.9 kB ? eta -:--:--
#    ---------------------------------------- 97.9/97.9 kB 1.9 MB/s eta 0:00:00
# Downloading joblib-1.4.2-py3-none-any.whl (301 kB)
#    ---------------------------------------- 0.0/301.8 kB ? eta -:--:--
#    ----------------------------------- ---- 266.2/301.8 kB 8.3 MB/s eta 0:00:01
#    ---------------------------------------- 301.8/301.8 kB 3.7 MB/s eta 0:00:00
# Downloading tqdm-4.66.5-py3-none-any.whl (78 kB)
#    ---------------------------------------- 0.0/78.4 kB ? eta -:--:--
#    ---------------------------------------- 78.4/78.4 kB 1.1 MB/s eta 0:00:00
# Installing collected packages: tqdm, regex, joblib, click, nltk
# Successfully installed click-8.1.7 joblib-1.4.2 nltk-3.9.1 regex-2024.9.11 tqdm-4.66.5
# [notice] A new release of pip is available: 23.2.1 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Collecting scikit-learn
#   Obtaining dependency information for scikit-learn from https://files.pythonhosted.org/packages/52/2d/ad6928a578c78bb0e44e34a5a922818b14c56716b81d145924f1f291416f/scikit_learn-1.3.2-cp38-cp38-win_amd64.whl.metadata
#   Downloading scikit_learn-1.3.2-cp38-cp38-win_amd64.whl.metadata (11 kB)
# Requirement already satisfied: numpy<2.0,>=1.17.3 in f:\data-collection-and-markup_9\pythonproject\.venv\lib\site-packages (from scikit-learn) (1.24.4)
# Collecting scipy>=1.5.0 (from scikit-learn)
#   Obtaining dependency information for scipy>=1.5.0 from https://files.pythonhosted.org/packages/32/8e/7f403535ddf826348c9b8417791e28712019962f7e90ff845896d6325d09/scipy-1.10.1-cp38-cp38-win_amd64.whl.metadata
#   Downloading scipy-1.10.1-cp38-cp38-win_amd64.whl.metadata (58 kB)
#      ---------------------------------------- 0.0/59.0 kB ? eta -:--:--
#      ---------------------------------------- 59.0/59.0 kB 1.0 MB/s eta 0:00:00
# Requirement already satisfied: joblib>=1.1.1 in f:\data-collection-and-markup_9\pythonproject\.venv\lib\site-packages (from scikit-learn) (1.4.2)
# Collecting threadpoolctl>=2.0.0 (from scikit-learn)
#   Obtaining dependency information for threadpoolctl>=2.0.0 from https://files.pythonhosted.org/packages/4b/2c/ffbf7a134b9ab11a67b0cf0726453cedd9c5043a4fe7a35d1cefa9a1bcfb/threadpoolctl-3.5.0-py3-none-any.whl.metadata
#   Downloading threadpoolctl-3.5.0-py3-none-any.whl.metadata (13 kB)
# Downloading scikit_learn-1.3.2-cp38-cp38-win_amd64.whl (9.3 MB)
#    ---------------------------------------- 0.0/9.3 MB ? eta -:--:--
#     --------------------------------------- 0.2/9.3 MB 4.6 MB/s eta 0:00:02
#    -- ------------------------------------- 0.7/9.3 MB 5.3 MB/s eta 0:00:02
#    ---- ----------------------------------- 1.1/9.3 MB 6.0 MB/s eta 0:00:02
#    ------- -------------------------------- 1.8/9.3 MB 7.1 MB/s eta 0:00:02
#    ------- -------------------------------- 1.8/9.3 MB 7.1 MB/s eta 0:00:02
#    --------------- ------------------------ 3.6/9.3 MB 8.2 MB/s eta 0:00:01
#    ----------------- ---------------------- 4.1/9.3 MB 7.9 MB/s eta 0:00:01
#    -------------------- ------------------- 4.7/9.3 MB 7.9 MB/s eta 0:00:01
#    ---------------------- ----------------- 5.2/9.3 MB 7.9 MB/s eta 0:00:01
#    ------------------------------ --------- 7.0/9.3 MB 8.7 MB/s eta 0:00:01
#    -------------------------------- ------- 7.5/9.3 MB 8.5 MB/s eta 0:00:01
#    --------------------------------- ------ 7.8/9.3 MB 8.3 MB/s eta 0:00:01
#    ----------------------------------- ---- 8.3/9.3 MB 8.5 MB/s eta 0:00:01
#    ---------------------------------------  9.1/9.3 MB 8.7 MB/s eta 0:00:01
#    ---------------------------------------  9.3/9.3 MB 8.7 MB/s eta 0:00:01
#    ---------------------------------------  9.3/9.3 MB 8.7 MB/s eta 0:00:01
#    ---------------------------------------  9.3/9.3 MB 8.7 MB/s eta 0:00:01
#    ---------------------------------------- 9.3/9.3 MB 7.2 MB/s eta 0:00:00
# Downloading scipy-1.10.1-cp38-cp38-win_amd64.whl (42.2 MB)
#    ---------------------------------------- 0.0/42.2 MB ? eta -:--:--
#     --------------------------------------- 0.9/42.2 MB 11.6 MB/s eta 0:00:04
#    - -------------------------------------- 1.9/42.2 MB 10.9 MB/s eta 0:00:04
#    -- ------------------------------------- 2.8/42.2 MB 11.1 MB/s eta 0:00:04
#    --- ------------------------------------ 3.9/42.2 MB 11.3 MB/s eta 0:00:04
#    ---- ----------------------------------- 4.7/42.2 MB 10.7 MB/s eta 0:00:04
#    ----- ---------------------------------- 5.4/42.2 MB 10.2 MB/s eta 0:00:04
#    ----- ---------------------------------- 5.7/42.2 MB 9.6 MB/s eta 0:00:04
#    ------ --------------------------------- 6.7/42.2 MB 9.7 MB/s eta 0:00:04
#    ------- -------------------------------- 7.9/42.2 MB 10.3 MB/s eta 0:00:04
#    -------- ------------------------------- 8.8/42.2 MB 10.6 MB/s eta 0:00:04
#    ---------- ----------------------------- 11.1/42.2 MB 10.9 MB/s eta 0:00:03
#    ----------- ---------------------------- 12.4/42.2 MB 10.9 MB/s eta 0:00:03
#    ------------- -------------------------- 13.9/42.2 MB 10.4 MB/s eta 0:00:03
#    ------------- -------------------------- 14.6/42.2 MB 10.6 MB/s eta 0:00:03
#    -------------- ------------------------- 15.7/42.2 MB 10.7 MB/s eta 0:00:03
#    ---------------- ----------------------- 17.3/42.2 MB 11.3 MB/s eta 0:00:03
#    ---------------- ----------------------- 17.6/42.2 MB 10.9 MB/s eta 0:00:03
#    ------------------ --------------------- 19.3/42.2 MB 10.4 MB/s eta 0:00:03
#    -------------------- ------------------- 21.4/42.2 MB 9.9 MB/s eta 0:00:03
#    -------------------- ------------------- 22.1/42.2 MB 9.9 MB/s eta 0:00:03
#    ---------------------- ----------------- 23.4/42.2 MB 10.1 MB/s eta 0:00:02
#    ---------------------- ----------------- 24.0/42.2 MB 9.8 MB/s eta 0:00:02
#    ----------------------- ---------------- 24.8/42.2 MB 9.8 MB/s eta 0:00:02
#    ------------------------ --------------- 25.7/42.2 MB 9.8 MB/s eta 0:00:02
#    ------------------------- -------------- 26.4/42.2 MB 9.8 MB/s eta 0:00:02
#    ------------------------- -------------- 27.4/42.2 MB 9.4 MB/s eta 0:00:02
#    -------------------------- ------------- 28.1/42.2 MB 9.5 MB/s eta 0:00:02
#    --------------------------- ------------ 28.5/42.2 MB 9.4 MB/s eta 0:00:02
#    ---------------------------- ----------- 30.1/42.2 MB 9.8 MB/s eta 0:00:02
#    ----------------------------- ---------- 30.8/42.2 MB 9.9 MB/s eta 0:00:02
#    ----------------------------- ---------- 30.9/42.2 MB 9.6 MB/s eta 0:00:02
#    ------------------------------ --------- 32.0/42.2 MB 9.6 MB/s eta 0:00:02
#    ------------------------------ --------- 32.3/42.2 MB 9.4 MB/s eta 0:00:02
#    ------------------------------- -------- 32.8/42.2 MB 9.1 MB/s eta 0:00:02
#    ------------------------------- -------- 33.1/42.2 MB 8.8 MB/s eta 0:00:02
#    -------------------------------- ------- 34.6/42.2 MB 8.8 MB/s eta 0:00:01
#    ----------------------------------- ---- 37.1/42.2 MB 9.4 MB/s eta 0:00:01
#    ----------------------------------- ---- 37.5/42.2 MB 8.5 MB/s eta 0:00:01
#    ------------------------------------ --- 38.6/42.2 MB 8.0 MB/s eta 0:00:01
#    ------------------------------------- -- 39.8/42.2 MB 7.8 MB/s eta 0:00:01
#    ---------------------------------------  41.6/42.2 MB 8.1 MB/s eta 0:00:01
#    ---------------------------------------  42.2/42.2 MB 7.9 MB/s eta 0:00:01
#    ---------------------------------------  42.2/42.2 MB 7.9 MB/s eta 0:00:01
#    ---------------------------------------  42.2/42.2 MB 7.9 MB/s eta 0:00:01
#    ---------------------------------------  42.2/42.2 MB 7.9 MB/s eta 0:00:01
#    ---------------------------------------  42.2/42.2 MB 7.9 MB/s eta 0:00:01
#    ---------------------------------------  42.2/42.2 MB 7.9 MB/s eta 0:00:01
#    ---------------------------------------  42.2/42.2 MB 7.9 MB/s eta 0:00:01
#    ---------------------------------------  42.2/42.2 MB 7.9 MB/s eta 0:00:01
#    ---------------------------------------  42.2/42.2 MB 7.9 MB/s eta 0:00:01
#    ---------------------------------------  42.2/42.2 MB 7.9 MB/s eta 0:00:01
#    ---------------------------------------- 42.2/42.2 MB 4.2 MB/s eta 0:00:00
# Downloading threadpoolctl-3.5.0-py3-none-any.whl (18 kB)
# Installing collected packages: threadpoolctl, scipy, scikit-learn
# Successfully installed scikit-learn-1.3.2 scipy-1.10.1 threadpoolctl-3.5.0
# [notice] A new release of pip is available: 23.2.1 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Collecting label-studio
#   Obtaining dependency information for label-studio from https://files.pythonhosted.org/packages/02/d1/4db0730f7b53eaa22d7decab4155d00184e086363138552ff4594dcdf896/label_studio-1.13.1-py3-none-any.whl.metadata
#   Using cached label_studio-1.13.1-py3-none-any.whl.metadata (14 kB)
# Collecting Django<3.3.0,>=3.2.24 (from label-studio)
#   Obtaining dependency information for Django<3.3.0,>=3.2.24 from https://files.pythonhosted.org/packages/30/8e/cc23c762c5dcd1d367d73cf006a326e0df2bd0e785cba18b658b39904c1e/Django-3.2.25-py3-none-any.whl.metadata
#   Using cached Django-3.2.25-py3-none-any.whl.metadata (4.1 kB)
# Collecting appdirs>=1.4.3 (from label-studio)
#   Obtaining dependency information for appdirs>=1.4.3 from https://files.pythonhosted.org/packages/3b/00/2344469e2084fb287c2e0b57b72910309874c3245463acd6cf5e3db69324/appdirs-1.4.4-py2.py3-none-any.whl.metadata
#   Downloading appdirs-1.4.4-py2.py3-none-any.whl.metadata (9.0 kB)
# Collecting attr==0.3.1 (from label-studio)
#   Using cached attr-0.3.1.tar.gz (1.7 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: attrs>=19.2.0 in f:\data-collection-and-markup_9\pythonproject\.venv\lib\site-packages (from label-studio) (24.2.0)
# Collecting azure-storage-blob>=12.6.0 (from label-studio)
#   Obtaining dependency information for azure-storage-blob>=12.6.0 from https://files.pythonhosted.org/packages/df/bf/f19dd2261dd6193aa53375fcd58929d613e45d14bcdb778567d1fd5e2d6e/azure_storage_blob-12.23.1-py3-none-any.whl.metadata
#   Using cached azure_storage_blob-12.23.1-py3-none-any.whl.metadata (26 kB)
# Collecting bleach<5.1.0,>=5.0.0 (from label-studio)
#   Obtaining dependency information for bleach<5.1.0,>=5.0.0 from https://files.pythonhosted.org/packages/d4/87/508104336a2bc0c4cfdbdceedc0f44dc72da3abc0460c57e323ddd1b3257/bleach-5.0.1-py3-none-any.whl.metadata
#   Using cached bleach-5.0.1-py3-none-any.whl.metadata (27 kB)
# Collecting boto<3.0.0,>=2.49.0 (from label-studio)
#   Obtaining dependency information for boto<3.0.0,>=2.49.0 from https://files.pythonhosted.org/packages/23/10/c0b78c27298029e4454a472a1919bde20cb182dab1662cec7f2ca1dcc523/boto-2.49.0-py2.py3-none-any.whl.metadata
#   Using cached boto-2.49.0-py2.py3-none-any.whl.metadata (7.3 kB)
# Collecting boto3<2.0.0,>=1.28.58 (from label-studio)
#   Obtaining dependency information for boto3<2.0.0,>=1.28.58 from https://files.pythonhosted.org/packages/47/0c/5646287d1f4aeab4e0b55e517935d2debba6bce47cc0542ab618868b18d3/boto3-1.35.29-py3-none-any.whl.metadata
#   Using cached boto3-1.35.29-py3-none-any.whl.metadata (6.6 kB)
# Collecting botocore<2.0.0,>=1.31.58 (from label-studio)
#   Obtaining dependency information for botocore<2.0.0,>=1.31.58 from https://files.pythonhosted.org/packages/8a/eb/30c1bf5dc2ec8829baee4d8423da5b63ae2c9f7678d809ef2e375fd67212/botocore-1.35.29-py3-none-any.whl.metadata
#   Using cached botocore-1.35.29-py3-none-any.whl.metadata (5.6 kB)
# Collecting boxing>=0.1.4 (from label-studio)
#   Obtaining dependency information for boxing>=0.1.4 from https://files.pythonhosted.org/packages/59/a1/741fe3179bbeb1e2097012e622beccaa93e9e1c905bc4450e47e3297686b/boxing-0.1.4-py3-none-any.whl.metadata
#   Using cached boxing-0.1.4-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: colorama>=0.4.4 in f:\data-collection-and-markup_9\pythonproject\.venv\lib\site-packages (from label-studio) (0.4.6)
# Requirement already satisfied: defusedxml>=0.7.1 in f:\data-collection-and-markup_9\pythonproject\.venv\lib\site-packages (from label-studio) (0.7.1)
# Collecting django-annoying==0.10.6 (from label-studio)
#   Obtaining dependency information for django-annoying==0.10.6 from https://files.pythonhosted.org/packages/38/56/a347666a12aca588f8a689a56edee0930c295662f166b3f4f1775c7c91c3/django_annoying-0.10.6-py2.py3-none-any.whl.metadata
#   Using cached django_annoying-0.10.6-py2.py3-none-any.whl.metadata (2.3 kB)
# Collecting django-cors-headers==3.6.0 (from label-studio)
#   Obtaining dependency information for django-cors-headers==3.6.0 from https://files.pythonhosted.org/packages/20/ef/d51852e83740b5be3f995daf2fe23be3c615032f65e7b0cd3811c74fbcae/django_cors_headers-3.6.0-py3-none-any.whl.metadata
#   Using cached django_cors_headers-3.6.0-py3-none-any.whl.metadata (14 kB)
# Collecting django-csp==3.7 (from label-studio)
#   Obtaining dependency information for django-csp==3.7 from https://files.pythonhosted.org/packages/43/04/1e3b703e584fef3522065415d9b2f7550d8996d7e590d9b70b8c480ecc69/django_csp-3.7-py2.py3-none-any.whl.metadata
#   Using cached django_csp-3.7-py2.py3-none-any.whl.metadata (2.7 kB)
# Collecting django-debug-toolbar==3.2.1 (from label-studio)
#   Obtaining dependency information for django-debug-toolbar==3.2.1 from https://files.pythonhosted.org/packages/26/0e/cc77743f07bf0812c3852385f94c76e6e671c4c8f1b248bb44dbdf157180/django_debug_toolbar-3.2.1-py3-none-any.whl.metadata
#   Using cached django_debug_toolbar-3.2.1-py3-none-any.whl.metadata (3.2 kB)
# Collecting django-environ==0.10.0 (from label-studio)
#   Obtaining dependency information for django-environ==0.10.0 from https://files.pythonhosted.org/packages/28/54/caed659e2f0629693b899fb1c0307919b1a7e29d7052e7f9fb3bb3ddc5ef/django_environ-0.10.0-py2.py3-none-any.whl.metadata
#   Using cached django_environ-0.10.0-py2.py3-none-any.whl.metadata (13 kB)
# Collecting django-extensions==3.1.0 (from label-studio)
#   Obtaining dependency information for django-extensions==3.1.0 from https://files.pythonhosted.org/packages/1a/e1/3e5142f101869b665820bc71d317706eb1abdb1302f83728b1248258dc49/django_extensions-3.1.0-py3-none-any.whl.metadata
#   Using cached django_extensions-3.1.0-py3-none-any.whl.metadata (5.0 kB)
# Collecting django-filter==2.4.0 (from label-studio)
#   Obtaining dependency information for django-filter==2.4.0 from https://files.pythonhosted.org/packages/71/2b/b2fe483c3095b6222725dd05f9ad9e6ed6cb7347c154fdbd80238d36f1a8/django_filter-2.4.0-py3-none-any.whl.metadata
#   Using cached django_filter-2.4.0-py3-none-any.whl.metadata (4.1 kB)
# Collecting django-model-utils==4.1.1 (from label-studio)
#   Obtaining dependency information for django-model-utils==4.1.1 from https://files.pythonhosted.org/packages/c4/4d/3a1fc03a0e3dd5fafec7eeed39ef198972d44281df2624de77a2119b21a4/django_model_utils-4.1.1-py3-none-any.whl.metadata
#   Using cached django_model_utils-4.1.1-py3-none-any.whl.metadata (17 kB)
# Collecting django-ranged-fileresponse>=0.1.2 (from label-studio)
#   Using cached django-ranged-fileresponse-0.1.2.tar.gz (2.7 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting django-rq==2.5.1 (from label-studio)
#   Obtaining dependency information for django-rq==2.5.1 from https://files.pythonhosted.org/packages/4e/d3/c88bfa005a49c0d6ba55251e88cb87d17fa4871c0232a3ae927e00819c78/django_rq-2.5.1-py2.py3-none-any.whl.metadata
#   Using cached django_rq-2.5.1-py2.py3-none-any.whl.metadata (17 kB)
# Collecting django-storages==1.12.3 (from label-studio)
#   Obtaining dependency information for django-storages==1.12.3 from https://files.pythonhosted.org/packages/13/f9/61740c0224454142354914e539d06dd49c6eb8bd863a583a1624acdf6c02/django_storages-1.12.3-py3-none-any.whl.metadata
#   Using cached django_storages-1.12.3-py3-none-any.whl.metadata (54 kB)
# Collecting django-user-agents==0.4.0 (from label-studio)
#   Obtaining dependency information for django-user-agents==0.4.0 from https://files.pythonhosted.org/packages/6c/a3/31b2728702f13328cc65d6c8ed652ad8125a9a71489e445c11f188b39f79/django_user_agents-0.4.0-py3-none-any.whl.metadata
#   Using cached django_user_agents-0.4.0-py3-none-any.whl.metadata (6.2 kB)
# Collecting djangorestframework==3.13.1 (from label-studio)
#   Obtaining dependency information for djangorestframework==3.13.1 from https://files.pythonhosted.org/packages/c8/45/2588c7c5a01a7da6822c6ffbc9a731d498c318a803a29ae780ec635ea41d/djangorestframework-3.13.1-py3-none-any.whl.metadata
#   Using cached djangorestframework-3.13.1-py3-none-any.whl.metadata (10 kB)
# Collecting drf-dynamic-fields==0.3.0 (from label-studio)
#   Obtaining dependency information for drf-dynamic-fields==0.3.0 from https://files.pythonhosted.org/packages/5b/1e/53b0534ea981eb62b4e0cc695e589586b4d111cc0e2e4bbad498f32d2b3f/drf_dynamic_fields-0.3.0-py2.py3-none-any.whl.metadata
#   Using cached drf_dynamic_fields-0.3.0-py2.py3-none-any.whl.metadata (4.8 kB)
# Collecting drf-flex-fields==0.9.5 (from label-studio)
#   Using cached drf-flex-fields-0.9.5.tar.gz (27 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting drf-generators==0.3.0 (from label-studio)
#   Using cached drf-generators-0.3.0.tar.gz (9.4 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting google-cloud-logging<4.0.0,>=3.10.0 (from label-studio)
#   Obtaining dependency information for google-cloud-logging<4.0.0,>=3.10.0 from https://files.pythonhosted.org/packages/c6/17/d1434fd1b725eae60542085d3082c1a7b881f34e3f7d299474805296b77d/google_cloud_logging-3.11.2-py2.py3-none-any.whl.metadata
#   Using cached google_cloud_logging-3.11.2-py2.py3-none-any.whl.metadata (4.9 kB)
# Collecting google-cloud-storage<3.0.0,>=2.13.0 (from label-studio)
#   Obtaining dependency information for google-cloud-storage<3.0.0,>=2.13.0 from https://files.pythonhosted.org/packages/fc/da/95db7bd4f0bd1644378ac1702c565c0210b004754d925a74f526a710c087/google_cloud_storage-2.18.2-py2.py3-none-any.whl.metadata
#   Using cached google_cloud_storage-2.18.2-py2.py3-none-any.whl.metadata (9.1 kB)
# Collecting htmlmin==0.1.12 (from label-studio)
#   Using cached htmlmin-0.1.12.tar.gz (19 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting humansignal-drf-yasg>=1.21.9 (from label-studio)
#   Obtaining dependency information for humansignal-drf-yasg>=1.21.9 from https://files.pythonhosted.org/packages/c6/a2/5e2244b635174dd028be49a75227b91fc62200b321dbd02247f2fbfeba73/humansignal_drf_yasg-1.21.9-py3-none-any.whl.metadata
#   Using cached humansignal_drf_yasg-1.21.9-py3-none-any.whl.metadata (15 kB)
# Collecting jsonschema==3.2.0 (from label-studio)
#   Obtaining dependency information for jsonschema==3.2.0 from https://files.pythonhosted.org/packages/c5/8f/51e89ce52a085483359217bc72cdbf6e75ee595d5b1d4b5ade40c7e018b8/jsonschema-3.2.0-py2.py3-none-any.whl.metadata
#   Using cached jsonschema-3.2.0-py2.py3-none-any.whl.metadata (7.8 kB)
# Collecting label-studio-sdk==1.0.5 (from label-studio)
#   Obtaining dependency information for label-studio-sdk==1.0.5 from https://files.pythonhosted.org/packages/18/d2/581b38e782c2e6032bfa8e75df83db9ab2295edc674ea285b469a74d8115/label_studio_sdk-1.0.5-py3-none-any.whl.metadata
#   Using cached label_studio_sdk-1.0.5-py3-none-any.whl.metadata (5.5 kB)
# Collecting launchdarkly-server-sdk==8.2.1 (from label-studio)
#   Obtaining dependency information for launchdarkly-server-sdk==8.2.1 from https://files.pythonhosted.org/packages/57/2e/c20d7024358dbcbb92cd851ee1c5f3ed9d4aaba19b473b2973dcbc07624a/launchdarkly_server_sdk-8.2.1-py3-none-any.whl.metadata
#   Using cached launchdarkly_server_sdk-8.2.1-py3-none-any.whl.metadata (1.3 kB)
# Collecting lockfile>=0.12.0 (from label-studio)
#   Obtaining dependency information for lockfile>=0.12.0 from https://files.pythonhosted.org/packages/c8/22/9460e311f340cb62d26a38c419b1381b8593b0bb6b5d1f056938b086d362/lockfile-0.12.2-py2.py3-none-any.whl.metadata
#   Using cached lockfile-0.12.2-py2.py3-none-any.whl.metadata (2.4 kB)
# Collecting lxml>=4.2.5 (from label-studio)
#   Obtaining dependency information for lxml>=4.2.5 from https://files.pythonhosted.org/packages/80/56/395e289a6ec501e1cfddd0016d38bda2d4a54cca0d962d1cb8a35b582ad8/lxml-5.3.0-cp38-cp38-win_amd64.whl.metadata
#   Downloading lxml-5.3.0-cp38-cp38-win_amd64.whl.metadata (3.9 kB)
# Requirement already satisfied: numpy<2.0.0,>=1.24.3 in f:\data-collection-and-markup_9\pythonproject\.venv\lib\site-packages (from label-studio) (1.24.4)
# Collecting openai<2.0.0,>=1.10.0 (from label-studio)
#   Obtaining dependency information for openai<2.0.0,>=1.10.0 from https://files.pythonhosted.org/packages/ee/49/7baf2537d7eedb162c8212e973bd69fe7233b463118e469bdb1bb07506f6/openai-1.50.2-py3-none-any.whl.metadata
#   Using cached openai-1.50.2-py3-none-any.whl.metadata (24 kB)
# Collecting ordered-set==4.0.2 (from label-studio)
#   Using cached ordered-set-4.0.2.tar.gz (10 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: pandas>=0.24.0 in f:\data-collection-and-markup_9\pythonproject\.venv\lib\site-packages (from label-studio) (2.0.3)
# Collecting psycopg2-binary==2.9.9 (from label-studio)
#   Obtaining dependency information for psycopg2-binary==2.9.9 from https://files.pythonhosted.org/packages/48/10/320b014e2fda509dc16409f76815ad0229e4fcec5ed229e64f7f917cc23f/psycopg2_binary-2.9.9-cp38-cp38-win_amd64.whl.metadata
#   Downloading psycopg2_binary-2.9.9-cp38-cp38-win_amd64.whl.metadata (4.5 kB)
# Collecting pydantic>=2.7.3 (from label-studio)
#   Obtaining dependency information for pydantic>=2.7.3 from https://files.pythonhosted.org/packages/df/e4/ba44652d562cbf0bf320e0f3810206149c8a4e99cdbf66da82e97ab53a15/pydantic-2.9.2-py3-none-any.whl.metadata
#   Using cached pydantic-2.9.2-py3-none-any.whl.metadata (149 kB)
# Requirement already satisfied: python-dateutil>=2.8.1 in f:\data-collection-and-markup_9\pythonproject\.venv\lib\site-packages (from label-studio) (2.9.0.post0)
# Collecting python-json-logger==2.0.4 (from label-studio)
#   Obtaining dependency information for python-json-logger==2.0.4 from https://files.pythonhosted.org/packages/cd/c7/beaf6614f94fcaf02f7f2e6dd29c15a4d4da863ee13b7a791964be24e87b/python_json_logger-2.0.4-py3-none-any.whl.metadata
#   Using cached python_json_logger-2.0.4-py3-none-any.whl.metadata (6.5 kB)
# Collecting pytz<2023.0,>=2022.1 (from label-studio)
#   Obtaining dependency information for pytz<2023.0,>=2022.1 from https://files.pythonhosted.org/packages/2e/09/fbd3c46dce130958ee8e0090f910f1fe39e502cc5ba0aadca1e8a2b932e5/pytz-2022.7.1-py2.py3-none-any.whl.metadata
#   Using cached pytz-2022.7.1-py2.py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: pyyaml>=6.0.0 in f:\data-collection-and-markup_9\pythonproject\.venv\lib\site-packages (from label-studio) (6.0.2)
# Collecting redis<4.0,>=3.5 (from label-studio)
#   Obtaining dependency information for redis<4.0,>=3.5 from https://files.pythonhosted.org/packages/a7/7c/24fb0511df653cf1a5d938d8f5d19802a88cef255706fdda242ff97e91b7/redis-3.5.3-py2.py3-none-any.whl.metadata
#   Using cached redis-3.5.3-py2.py3-none-any.whl.metadata (36 kB)
# Requirement already satisfied: requests<2.33.0,>=2.32.3 in f:\data-collection-and-markup_9\pythonproject\.venv\lib\site-packages (from label-studio) (2.32.3)
# Collecting rq==1.10.1 (from label-studio)
#   Obtaining dependency information for rq==1.10.1 from https://files.pythonhosted.org/packages/46/ff/4386cbd87b64664ba5279158024fe2e2bc40be8cab2a685e79a3dcca380d/rq-1.10.1-py2.py3-none-any.whl.metadata
#   Using cached rq-1.10.1-py2.py3-none-any.whl.metadata (1.6 kB)
# Collecting rules==2.2 (from label-studio)
#   Using cached rules-2.2.tar.gz (53 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting sentry-sdk>=1.1.0 (from label-studio)
#   Obtaining dependency information for sentry-sdk>=1.1.0 from https://files.pythonhosted.org/packages/40/de/956ce1d71459fa1af0486ca141fc605ac16f7c8855750668ff663e2b436a/sentry_sdk-2.14.0-py2.py3-none-any.whl.metadata
#   Using cached sentry_sdk-2.14.0-py2.py3-none-any.whl.metadata (9.7 kB)
# Collecting ujson>=3.0.0 (from label-studio)
#   Obtaining dependency information for ujson>=3.0.0 from https://files.pythonhosted.org/packages/d6/28/55e3890f814727aa984f66effa5e3e848863777409e96183c59e15152f73/ujson-5.10.0-cp38-cp38-win_amd64.whl.metadata
#   Downloading ujson-5.10.0-cp38-cp38-win_amd64.whl.metadata (9.5 kB)
# Collecting urllib3<2.0.0,>=1.26.18 (from label-studio)
#   Obtaining dependency information for urllib3<2.0.0,>=1.26.18 from https://files.pythonhosted.org/packages/33/cf/8435d5a7159e2a9c83a95896ed596f68cf798005fe107cc655b5c5c14704/urllib3-1.26.20-py2.py3-none-any.whl.metadata
#   Using cached urllib3-1.26.20-py2.py3-none-any.whl.metadata (50 kB)
# Collecting wheel<=0.40.0,>=0.38.1 (from label-studio)
#   Obtaining dependency information for wheel<=0.40.0,>=0.38.1 from https://files.pythonhosted.org/packages/61/86/cc8d1ff2ca31a312a25a708c891cf9facbad4eae493b3872638db6785eb5/wheel-0.40.0-py3-none-any.whl.metadata
#   Downloading wheel-0.40.0-py3-none-any.whl.metadata (2.1 kB)
# Collecting xmljson==0.2.1 (from label-studio)
#   Obtaining dependency information for xmljson==0.2.1 from https://files.pythonhosted.org/packages/91/2d/7191efe15406b8b99e2b5905ca676a8a3dc2936416ade7ed17752902c250/xmljson-0.2.1-py2.py3-none-any.whl.metadata
#   Using cached xmljson-0.2.1-py2.py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: six in f:\data-collection-and-markup_9\pythonproject\.venv\lib\site-packages (from django-annoying==0.10.6->label-studio) (1.16.0)
# Collecting sqlparse>=0.2.0 (from django-debug-toolbar==3.2.1->label-studio)
#   Obtaining dependency information for sqlparse>=0.2.0 from https://files.pythonhosted.org/packages/5d/a5/b2860373aa8de1e626b2bdfdd6df4355f0565b47e51f7d0c54fe70faf8fe/sqlparse-0.5.1-py3-none-any.whl.metadata
#   Using cached sqlparse-0.5.1-py3-none-any.whl.metadata (3.9 kB)
# Collecting user-agents (from django-user-agents==0.4.0->label-studio)
#   Obtaining dependency information for user-agents from https://files.pythonhosted.org/packages/8f/1c/20bb3d7b2bad56d881e3704131ddedbb16eb787101306887dff349064662/user_agents-2.2.0-py3-none-any.whl.metadata
#   Using cached user_agents-2.2.0-py3-none-any.whl.metadata (7.9 kB)
# Collecting pyrsistent>=0.14.0 (from jsonschema==3.2.0->label-studio)
#   Obtaining dependency information for pyrsistent>=0.14.0 from https://files.pythonhosted.org/packages/09/6a/6a31c1bbffd4880a8825cea2572e8b3082681215464ebec9404c0b74ab4c/pyrsistent-0.20.0-cp38-cp38-win_amd64.whl.metadata
#   Downloading pyrsistent-0.20.0-cp38-cp38-win_amd64.whl.metadata (976 bytes)
# Requirement already satisfied: setuptools in f:\data-collection-and-markup_9\pythonproject\.venv\lib\site-packages (from jsonschema==3.2.0->label-studio) (68.2.0)
# Collecting Pillow>=10.0.1 (from label-studio-sdk==1.0.5->label-studio)
#   Obtaining dependency information for Pillow>=10.0.1 from https://files.pythonhosted.org/packages/f2/75/3cb820b2812405fc7feb3d0deb701ef0c3de93dc02597115e00704591bc9/pillow-10.4.0-cp38-cp38-win_amd64.whl.metadata
#   Downloading pillow-10.4.0-cp38-cp38-win_amd64.whl.metadata (9.3 kB)
# Requirement already satisfied: httpx>=0.21.2 in f:\data-collection-and-markup_9\pythonproject\.venv\lib\site-packages (from label-studio-sdk==1.0.5->label-studio) (0.27.2)
# Collecting ijson>=3.2.3 (from label-studio-sdk==1.0.5->label-studio)
#   Obtaining dependency information for ijson>=3.2.3 from https://files.pythonhosted.org/packages/24/18/0707991e3b160b96e50d3425745986c1a0f8afd346b175a5716b71fa28cc/ijson-3.3.0-cp38-cp38-win_amd64.whl.metadata
#   Downloading ijson-3.3.0-cp38-cp38-win_amd64.whl.metadata (22 kB)
# Requirement already satisfied: nltk<4.0.0,>=3.8.2 in f:\data-collection-and-markup_9\pythonproject\.venv\lib\site-packages (from label-studio-sdk==1.0.5->label-studio) (3.9.1)
# Collecting requests-mock==1.12.1 (from label-studio-sdk==1.0.5->label-studio)
#   Obtaining dependency information for requests-mock==1.12.1 from https://files.pythonhosted.org/packages/97/ec/889fbc557727da0c34a33850950310240f2040f3b1955175fdb2b36a8910/requests_mock-1.12.1-py2.py3-none-any.whl.metadata
#   Using cached requests_mock-1.12.1-py2.py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: typing_extensions>=4.0.0 in f:\data-collection-and-markup_9\pythonproject\.venv\lib\site-packages (from label-studio-sdk==1.0.5->label-studio) (4.12.2)
# Requirement already satisfied: certifi>=2018.4.16 in f:\data-collection-and-markup_9\pythonproject\.venv\lib\site-packages (from launchdarkly-server-sdk==8.2.1->label-studio) (2024.8.30)
# Collecting expiringdict>=1.1.4 (from launchdarkly-server-sdk==8.2.1->label-studio)
#   Obtaining dependency information for expiringdict>=1.1.4 from https://files.pythonhosted.org/packages/cb/84/a04c59324445f4bcc98dc05b39a1cd07c242dde643c1a3c21e4f7beaf2f2/expiringdict-1.2.2-py3-none-any.whl.metadata
#   Using cached expiringdict-1.2.2-py3-none-any.whl.metadata (3.7 kB)
# Collecting pyRFC3339>=1.0 (from launchdarkly-server-sdk==8.2.1->label-studio)
#   Obtaining dependency information for pyRFC3339>=1.0 from https://files.pythonhosted.org/packages/c1/7a/725f5c16756ec6211b1e7eeac09f469084595513917ea069bc023c40a5e2/pyRFC3339-1.1-py2.py3-none-any.whl.metadata
#   Using cached pyRFC3339-1.1-py2.py3-none-any.whl.metadata (2.0 kB)
# Collecting semver>=2.10.2 (from launchdarkly-server-sdk==8.2.1->label-studio)
#   Obtaining dependency information for semver>=2.10.2 from https://files.pythonhosted.org/packages/9a/77/0cc7a8a3bc7e53d07e8f47f147b92b0960e902b8254859f4aee5c4d7866b/semver-3.0.2-py3-none-any.whl.metadata
#   Using cached semver-3.0.2-py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: click>=5.0.0 in f:\data-collection-and-markup_9\pythonproject\.venv\lib\site-packages (from rq==1.10.1->label-studio) (8.1.7)
# Collecting azure-core>=1.30.0 (from azure-storage-blob>=12.6.0->label-studio)
#   Obtaining dependency information for azure-core>=1.30.0 from https://files.pythonhosted.org/packages/01/8e/fcb6a77d3029d2a7356f38dbc77cf7daa113b81ddab76b5593d23321e44c/azure_core-1.31.0-py3-none-any.whl.metadata
#   Using cached azure_core-1.31.0-py3-none-any.whl.metadata (39 kB)
# Collecting cryptography>=2.1.4 (from azure-storage-blob>=12.6.0->label-studio)
#   Obtaining dependency information for cryptography>=2.1.4 from https://files.pythonhosted.org/packages/cc/73/0eacbdc437202edcbdc07f3576ed8fb8b0ab79d27bf2c5d822d758a72faa/cryptography-43.0.1-cp37-abi3-win_amd64.whl.metadata
#   Downloading cryptography-43.0.1-cp37-abi3-win_amd64.whl.metadata (5.4 kB)
# Collecting isodate>=0.6.1 (from azure-storage-blob>=12.6.0->label-studio)
#   Obtaining dependency information for isodate>=0.6.1 from https://files.pythonhosted.org/packages/b6/85/7882d311924cbcfc70b1890780763e36ff0b140c7e51c110fc59a532f087/isodate-0.6.1-py2.py3-none-any.whl.metadata
#   Using cached isodate-0.6.1-py2.py3-none-any.whl.metadata (9.6 kB)
# Requirement already satisfied: webencodings in f:\data-collection-and-markup_9\pythonproject\.venv\lib\site-packages (from bleach<5.1.0,>=5.0.0->label-studio) (0.5.1)
# Collecting jmespath<2.0.0,>=0.7.1 (from boto3<2.0.0,>=1.28.58->label-studio)
#   Obtaining dependency information for jmespath<2.0.0,>=0.7.1 from https://files.pythonhosted.org/packages/31/b4/b9b800c45527aadd64d5b442f9b932b00648617eb5d63d2c7a6587b7cafc/jmespath-1.0.1-py3-none-any.whl.metadata
#   Downloading jmespath-1.0.1-py3-none-any.whl.metadata (7.6 kB)
# Collecting s3transfer<0.11.0,>=0.10.0 (from boto3<2.0.0,>=1.28.58->label-studio)
#   Obtaining dependency information for s3transfer<0.11.0,>=0.10.0 from https://files.pythonhosted.org/packages/3c/4a/b221409913760d26cf4498b7b1741d510c82d3ad38381984a3ddc135ec66/s3transfer-0.10.2-py3-none-any.whl.metadata
#   Using cached s3transfer-0.10.2-py3-none-any.whl.metadata (1.7 kB)
# Collecting asgiref<4,>=3.3.2 (from Django<3.3.0,>=3.2.24->label-studio)
#   Obtaining dependency information for asgiref<4,>=3.3.2 from https://files.pythonhosted.org/packages/39/e3/893e8757be2612e6c266d9bb58ad2e3651524b5b40cf56761e985a28b13e/asgiref-3.8.1-py3-none-any.whl.metadata
#   Using cached asgiref-3.8.1-py3-none-any.whl.metadata (9.3 kB)
# Collecting google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1 (from google-cloud-logging<4.0.0,>=3.10.0->label-studio)
#   Obtaining dependency information for google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1 from https://files.pythonhosted.org/packages/c8/dc/6143f67acf5f30717c9e1b1c48fc04c0f59b869be046e6639d3f171640ae/google_api_core-2.20.0-py3-none-any.whl.metadata
#   Using cached google_api_core-2.20.0-py3-none-any.whl.metadata (2.7 kB)
# Collecting google-auth!=2.24.0,!=2.25.0,<3.0.0dev,>=2.14.1 (from google-cloud-logging<4.0.0,>=3.10.0->label-studio)
#   Obtaining dependency information for google-auth!=2.24.0,!=2.25.0,<3.0.0dev,>=2.14.1 from https://files.pythonhosted.org/packages/27/1f/3a72917afcb0d5cd842cbccb81bf7a8a7b45b4c66d8dc4556ccb3b016bfc/google_auth-2.35.0-py2.py3-none-any.whl.metadata
#   Using cached google_auth-2.35.0-py2.py3-none-any.whl.metadata (4.7 kB)
# Collecting google-cloud-appengine-logging<2.0.0dev,>=0.1.3 (from google-cloud-logging<4.0.0,>=3.10.0->label-studio)
#   Obtaining dependency information for google-cloud-appengine-logging<2.0.0dev,>=0.1.3 from https://files.pythonhosted.org/packages/6f/74/e2a3c9a7bfe24ec39fe6529342f57bb2a0f667f476b663274c92edd6fc56/google_cloud_appengine_logging-1.4.5-py2.py3-none-any.whl.metadata
#   Using cached google_cloud_appengine_logging-1.4.5-py2.py3-none-any.whl.metadata (5.4 kB)
# Collecting google-cloud-audit-log<1.0.0dev,>=0.2.4 (from google-cloud-logging<4.0.0,>=3.10.0->label-studio)
#   Obtaining dependency information for google-cloud-audit-log<1.0.0dev,>=0.2.4 from https://files.pythonhosted.org/packages/f8/d9/d2795cae4a41781269413108cc7fcbfbcb595b89212216d56c4ce6e2482e/google_cloud_audit_log-0.3.0-py2.py3-none-any.whl.metadata
#   Using cached google_cloud_audit_log-0.3.0-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting google-cloud-core<3.0.0dev,>=2.0.0 (from google-cloud-logging<4.0.0,>=3.10.0->label-studio)
#   Obtaining dependency information for google-cloud-core<3.0.0dev,>=2.0.0 from https://files.pythonhosted.org/packages/5e/0f/2e2061e3fbcb9d535d5da3f58cc8de4947df1786fe6a1355960feb05a681/google_cloud_core-2.4.1-py2.py3-none-any.whl.metadata
#   Using cached google_cloud_core-2.4.1-py2.py3-none-any.whl.metadata (2.7 kB)
# Collecting grpc-google-iam-v1<1.0.0dev,>=0.12.4 (from google-cloud-logging<4.0.0,>=3.10.0->label-studio)
#   Obtaining dependency information for grpc-google-iam-v1<1.0.0dev,>=0.12.4 from https://files.pythonhosted.org/packages/a8/7d/da3875b7728bc700eeb28b513754ce237c04ac7cbf8559d76b0464ee01cb/grpc_google_iam_v1-0.13.1-py2.py3-none-any.whl.metadata
#   Using cached grpc_google_iam_v1-0.13.1-py2.py3-none-any.whl.metadata (3.3 kB)
# Collecting opentelemetry-api>=1.9.0 (from google-cloud-logging<4.0.0,>=3.10.0->label-studio)
#   Obtaining dependency information for opentelemetry-api>=1.9.0 from https://files.pythonhosted.org/packages/fb/1f/737dcdbc9fea2fa96c1b392ae47275165a7c641663fbb08a8d252968eed2/opentelemetry_api-1.27.0-py3-none-any.whl.metadata
#   Using cached opentelemetry_api-1.27.0-py3-none-any.whl.metadata (1.4 kB)
# Collecting proto-plus<2.0.0dev,>=1.22.0 (from google-cloud-logging<4.0.0,>=3.10.0->label-studio)
#   Obtaining dependency information for proto-plus<2.0.0dev,>=1.22.0 from https://files.pythonhosted.org/packages/7c/6f/db31f0711c0402aa477257205ce7d29e86a75cb52cd19f7afb585f75cda0/proto_plus-1.24.0-py3-none-any.whl.metadata
#   Using cached proto_plus-1.24.0-py3-none-any.whl.metadata (2.2 kB)
# Collecting protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.2 (from google-cloud-logging<4.0.0,>=3.10.0->label-studio)
#   Obtaining dependency information for protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.2 from https://files.pythonhosted.org/packages/1b/99/8d51383f6f326003e59cf1915e315803c9b786459bacf709e5edca158c5e/protobuf-5.28.2-cp38-cp38-win_amd64.whl.metadata
#   Downloading protobuf-5.28.2-cp38-cp38-win_amd64.whl.metadata (592 bytes)
# Collecting google-resumable-media>=2.7.2 (from google-cloud-storage<3.0.0,>=2.13.0->label-studio)
#   Obtaining dependency information for google-resumable-media>=2.7.2 from https://files.pythonhosted.org/packages/82/35/b8d3baf8c46695858cb9d8835a53baa1eeb9906ddaf2f728a5f5b640fd1e/google_resumable_media-2.7.2-py2.py3-none-any.whl.metadata
#   Using cached google_resumable_media-2.7.2-py2.py3-none-any.whl.metadata (2.2 kB)
# Collecting google-crc32c<2.0dev,>=1.0 (from google-cloud-storage<3.0.0,>=2.13.0->label-studio)
#   Obtaining dependency information for google-crc32c<2.0dev,>=1.0 from https://files.pythonhosted.org/packages/ad/42/f8d35568ae119d7485ab5d3838c0aff0739f175d38e319004203e39805b8/google_crc32c-1.5.0-cp38-cp38-win_amd64.whl.metadata
#   Downloading google_crc32c-1.5.0-cp38-cp38-win_amd64.whl.metadata (2.3 kB)
# Collecting inflection>=0.3.1 (from humansignal-drf-yasg>=1.21.9->label-studio)
#   Obtaining dependency information for inflection>=0.3.1 from https://files.pythonhosted.org/packages/59/91/aa6bde563e0085a02a435aa99b49ef75b0a4b062635e606dab23ce18d720/inflection-0.5.1-py2.py3-none-any.whl.metadata
#   Downloading inflection-0.5.1-py2.py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: packaging>=21.0 in f:\data-collection-and-markup_9\pythonproject\.venv\lib\site-packages (from humansignal-drf-yasg>=1.21.9->label-studio) (24.1)
# Collecting uritemplate>=3.0.0 (from humansignal-drf-yasg>=1.21.9->label-studio)
#   Obtaining dependency information for uritemplate>=3.0.0 from https://files.pythonhosted.org/packages/81/c0/7461b49cd25aeece13766f02ee576d1db528f1c37ce69aee300e075b485b/uritemplate-4.1.1-py2.py3-none-any.whl.metadata
#   Using cached uritemplate-4.1.1-py2.py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: anyio<5,>=3.5.0 in f:\data-collection-and-markup_9\pythonproject\.venv\lib\site-packages (from openai<2.0.0,>=1.10.0->label-studio) (4.5.0)
# Collecting distro<2,>=1.7.0 (from openai<2.0.0,>=1.10.0->label-studio)
#   Obtaining dependency information for distro<2,>=1.7.0 from https://files.pythonhosted.org/packages/12/b3/231ffd4ab1fc9d679809f356cebee130ac7daa00d6d6f3206dd4fd137e9e/distro-1.9.0-py3-none-any.whl.metadata
#   Using cached distro-1.9.0-py3-none-any.whl.metadata (6.8 kB)
# Collecting jiter<1,>=0.4.0 (from openai<2.0.0,>=1.10.0->label-studio)
#   Obtaining dependency information for jiter<1,>=0.4.0 from https://files.pythonhosted.org/packages/d2/9d/35771dc59a49aecc370c620949cf52f6841efc1edac4288def77ac85afb6/jiter-0.5.0-cp38-none-win_amd64.whl.metadata
#   Downloading jiter-0.5.0-cp38-none-win_amd64.whl.metadata (3.7 kB)
# Requirement already satisfied: sniffio in f:\data-collection-and-markup_9\pythonproject\.venv\lib\site-packages (from openai<2.0.0,>=1.10.0->label-studio) (1.3.1)
# Requirement already satisfied: tqdm>4 in f:\data-collection-and-markup_9\pythonproject\.venv\lib\site-packages (from openai<2.0.0,>=1.10.0->label-studio) (4.66.5)
# Requirement already satisfied: tzdata>=2022.1 in f:\data-collection-and-markup_9\pythonproject\.venv\lib\site-packages (from pandas>=0.24.0->label-studio) (2024.2)
# Collecting annotated-types>=0.6.0 (from pydantic>=2.7.3->label-studio)
#   Obtaining dependency information for annotated-types>=0.6.0 from https://files.pythonhosted.org/packages/78/b6/6307fbef88d9b5ee7421e68d78a9f162e0da4900bc5f5793f6d3d0e34fb8/annotated_types-0.7.0-py3-none-any.whl.metadata
#   Using cached annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.23.4 (from pydantic>=2.7.3->label-studio)
#   Obtaining dependency information for pydantic-core==2.23.4 from https://files.pythonhosted.org/packages/db/c8/e6ed2172bb2594a256c7756a70109fa31ab80d1cebb9003ad6c54e10c0d1/pydantic_core-2.23.4-cp38-none-win_amd64.whl.metadata
#   Downloading pydantic_core-2.23.4-cp38-none-win_amd64.whl.metadata (6.7 kB)
# ...
#   Building wheel for drf-flex-fields (setup.py): finished with status 'done'
#   Created wheel for drf-flex-fields: filename=drf_flex_fields-0.9.5-py3-none-any.whl size=14467 sha256=b72cd846a4e38f606228bad7988282698836749472735956a8143a98f7df6ea1
#   Stored in directory: c:\users\user\appdata\local\pip\cache\wheels\de\b4\34\9ed24713d77e921135bda46d7b9b4456262cbc48f1f028ded5
#   Building wheel for drf-generators (setup.py): started
#   Building wheel for drf-generators (setup.py): finished with status 'done'
#   Created wheel for drf-generators: filename=drf_generators-0.3.0-py2.py3-none-any.whl size=9807 sha256=209ca830435fe8a7c6d370ecb51a3b461f7981b6625830093d80fda9ff2ed40c
#   Stored in directory: c:\users\user\appdata\local\pip\cache\wheels\cf\68\01\a9b15f3472871cc9d9fbe608b34391c972330af8669725308e
#   Building wheel for htmlmin (setup.py): started
#   Building wheel for htmlmin (setup.py): finished with status 'done'
#   Created wheel for htmlmin: filename=htmlmin-0.1.12-py3-none-any.whl size=27091 sha256=e846168dbb43c7d083974d52e2177bc96dacc4a763bde29c2eda1bab0942a9f9
#   Stored in directory: c:\users\user\appdata\local\pip\cache\wheels\23\14\6e\4be5bfeeb027f4939a01764b48edd5996acf574b0913fe5243
#   Building wheel for ordered-set (setup.py): started
#   Building wheel for ordered-set (setup.py): finished with status 'done'
#   Created wheel for ordered-set: filename=ordered_set-4.0.2-py2.py3-none-any.whl size=8248 sha256=77093cf03b3e17491d8dedd9b4d3d3bccfee2f541a9772e81a81a36079dce1fa
#   Stored in directory: c:\users\user\appdata\local\pip\cache\wheels\a1\09\42\0b963b1d5423ddc87cb4ba9f475e09838d3813300b52a866ea
#   Building wheel for rules (setup.py): started
#   Building wheel for rules (setup.py): finished with status 'done'
#   Created wheel for rules: filename=rules-2.2-py2.py3-none-any.whl size=25967 sha256=fbe9df7e5e888a67c93e9f9f85ebba3d53dc5d7428b0c00db6b4be809e94c48a
#   Stored in directory: c:\users\user\appdata\local\pip\cache\wheels\c7\0c\ef\20cf4583d2360c0ea059e42e5325e6672e106afa4bb8362d85
#   Building wheel for django-ranged-fileresponse (setup.py): started
#   Building wheel for django-ranged-fileresponse (setup.py): finished with status 'done'
#   Created wheel for django-ranged-fileresponse: filename=django_ranged_fileresponse-0.1.2-py3-none-any.whl size=3236 sha256=8d9d33da44ae1857098fddebf19d0200bf3786588f0f7586f92afb8270130b7f
#   Stored in directory: c:\users\user\appdata\local\pip\cache\wheels\64\c6\12\0d423c91d49a8d033711e1328054b01022a3d093b1a8872554
# Successfully built attr drf-flex-fields drf-generators htmlmin ordered-set rules django-ranged-fileresponse
# Installing collected packages: xmljson, ua-parser, rules, pytz, lockfile, ijson, htmlmin, expiringdict, drf-flex-fields, drf-dynamic-fields, django-ranged-fileresponse, boxing, boto, attr, appdirs, wrapt, wheel, user-agents, urllib3, uritemplate, ujson, sqlparse, semver, redis, python-json-logger, pyrsistent, pyRFC3339, pydantic-core, pyasn1, psycopg2-binary, protobuf, Pillow, ordered-set, lxml, jmespath, jiter, isodate, inflection, importlib-metadata, grpcio, google-crc32c, django-extensions, django-environ, distro, cachetools, bleach, asgiref, annotated-types, sentry-sdk, rsa, rq, pydantic, pyasn1-modules, proto-plus, launchdarkly-server-sdk, jsonschema, googleapis-common-protos, google-resumable-media, Django, deprecated, cryptography, botocore, s3transfer, requests-mock, opentelemetry-api, openai, grpcio-status, google-cloud-audit-log, google-auth, drf-generators, djangorestframework, django-user-agents, django-storages, django-rq, django-model-utils, django-filter, django-debug-toolbar, django-csp, django-cors-headers, django-annoying, azure-core, label-studio-sdk, humansignal-drf-yasg, grpc-google-iam-v1, google-api-core, boto3, azure-storage-blob, google-cloud-core, google-cloud-storage, google-cloud-appengine-logging, google-cloud-logging, label-studio
#   Attempting uninstall: pytz
#     Found existing installation: pytz 2024.2
#     Uninstalling pytz-2024.2:
#       Successfully uninstalled pytz-2024.2
#   Attempting uninstall: wheel
#     Found existing installation: wheel 0.41.2
#     Uninstalling wheel-0.41.2:
#       Successfully uninstalled wheel-0.41.2
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 2.2.3
#     Uninstalling urllib3-2.2.3:
#       Successfully uninstalled urllib3-2.2.3
#   Attempting uninstall: python-json-logger
#     Found existing installation: python-json-logger 2.0.7
#     Uninstalling python-json-logger-2.0.7:
#       Successfully uninstalled python-json-logger-2.0.7
#   Attempting uninstall: importlib-metadata
#     Found existing installation: importlib_metadata 8.5.0
#     Uninstalling importlib_metadata-8.5.0:
#       Successfully uninstalled importlib_metadata-8.5.0
#   Attempting uninstall: bleach
#     Found existing installation: bleach 6.1.0
#     Uninstalling bleach-6.1.0:
#       Successfully uninstalled bleach-6.1.0
#   Attempting uninstall: jsonschema
#     Found existing installation: jsonschema 4.23.0
#     Uninstalling jsonschema-4.23.0:
#       Successfully uninstalled jsonschema-4.23.0
# Successfully installed Django-3.2.25 Pillow-10.4.0 annotated-types-0.7.0 appdirs-1.4.4 asgiref-3.8.1 attr-0.3.1 azure-core-1.31.0 azure-storage-blob-12.23.1 bleach-5.0.1 boto-2.49.0 boto3-1.35.29 botocore-1.35.29 boxing-0.1.4 cachetools-5.5.0 cryptography-43.0.1 deprecated-1.2.14 distro-1.9.0 django-annoying-0.10.6 django-cors-headers-3.6.0 django-csp-3.7 django-debug-toolbar-3.2.1 django-environ-0.10.0 django-extensions-3.1.0 django-filter-2.4.0 django-model-utils-4.1.1 django-ranged-fileresponse-0.1.2 django-rq-2.5.1 django-storages-1.12.3 django-user-agents-0.4.0 djangorestframework-3.13.1 drf-dynamic-fields-0.3.0 drf-flex-fields-0.9.5 drf-generators-0.3.0 expiringdict-1.2.2 google-api-core-2.20.0 google-auth-2.35.0 google-cloud-appengine-logging-1.4.5 google-cloud-audit-log-0.3.0 google-cloud-core-2.4.1 google-cloud-logging-3.11.2 google-cloud-storage-2.18.2 google-crc32c-1.5.0 google-resumable-media-2.7.2 googleapis-common-protos-1.65.0 grpc-google-iam-v1-0.13.1 grpcio-1.66.2 grpcio-status-1.66.2 htmlmin-0.1.12 humansignal-drf-yasg-1.21.9 ijson-3.3.0 importlib-metadata-8.4.0 inflection-0.5.1 isodate-0.6.1 jiter-0.5.0 jmespath-1.0.1 jsonschema-3.2.0 label-studio-1.13.1 label-studio-sdk-1.0.5 launchdarkly-server-sdk-8.2.1 lockfile-0.12.2 lxml-5.3.0 openai-1.50.2 opentelemetry-api-1.27.0 ordered-set-4.0.2 proto-plus-1.24.0 protobuf-5.28.2 psycopg2-binary-2.9.9 pyRFC3339-1.1 pyasn1-0.6.1 pyasn1-modules-0.4.1 pydantic-2.9.2 pydantic-core-2.23.4 pyrsistent-0.20.0 python-json-logger-2.0.4 pytz-2022.7.1 redis-3.5.3 requests-mock-1.12.1 rq-1.10.1 rsa-4.9 rules-2.2 s3transfer-0.10.2 semver-3.0.2 sentry-sdk-2.14.0 sqlparse-0.5.1 ua-parser-0.18.0 ujson-5.10.0 uritemplate-4.1.1 urllib3-1.26.20 user-agents-2.2.0 wheel-0.40.0 wrapt-1.16.0 xmljson-0.2.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# jupyter-events 0.10.0 requires jsonschema[format-nongpl]>=4.18.0, but you have jsonschema 3.2.0 which is incompatible.
# jupyterlab-server 2.27.3 requires jsonschema>=4.18.0, but you have jsonschema 3.2.0 which is incompatible.
#
# [notice] A new release of pip is available: 23.2.1 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Collecting matplotlib
#   Obtaining dependency information for matplotlib from https://files.pythonhosted.org/packages/16/51/58b0b9de42fe1e665736d9286f88b5f1556a0e22bed8a71f468231761083/matplotlib-3.7.5-cp38-cp38-win_amd64.whl.metadata
#   Downloading matplotlib-3.7.5-cp38-cp38-win_amd64.whl.metadata (5.8 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Obtaining dependency information for contourpy>=1.0.1 from https://files.pythonhosted.org/packages/96/1b/b05cd42c8d21767a0488b883b38658fb9a45f86c293b7b42521a8113dc5d/contourpy-1.1.1-cp38-cp38-win_amd64.whl.metadata
#   Downloading contourpy-1.1.1-cp38-cp38-win_amd64.whl.metadata (5.9 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Obtaining dependency information for cycler>=0.10 from https://files.pythonhosted.org/packages/e7/05/c19819d5e3d95294a6f5947fb9b9629efb316b96de511b418c53d245aae6/cycler-0.12.1-py3-none-any.whl.metadata
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Obtaining dependency information for fonttools>=4.22.0 from https://files.pythonhosted.org/packages/75/7f/3c4e038998d2a54b282d605f6aaac4c596c49d55add3adc6559a735bb4cb/fonttools-4.54.1-cp38-cp38-win_amd64.whl.metadata
#   Downloading fonttools-4.54.1-cp38-cp38-win_amd64.whl.metadata (167 kB)
#      ---------------------------------------- 0.0/167.0 kB ? eta -:--:--
#      --------------------- ----------------- 92.2/167.0 kB 1.7 MB/s eta 0:00:01
#      -------------------------------------  163.8/167.0 kB 1.7 MB/s eta 0:00:01
#      -------------------------------------- 167.0/167.0 kB 1.1 MB/s eta 0:00:00
# Collecting kiwisolver>=1.0.1 (from matplotlib)
#   Obtaining dependency information for kiwisolver>=1.0.1 from https://files.pythonhosted.org/packages/52/77/7e04cca2ff1dc6ee6b7654cebe233de72b7a3ec5616501b6f3144fb70740/kiwisolver-1.4.7-cp38-cp38-win_amd64.whl.metadata
#   Downloading kiwisolver-1.4.7-cp38-cp38-win_amd64.whl.metadata (6.4 kB)
# Requirement already satisfied: numpy<2,>=1.20 in f:\data-collection-and-markup_9\pythonproject\.venv\lib\site-packages (from matplotlib) (1.24.4)
# Requirement already satisfied: packaging>=20.0 in f:\data-collection-and-markup_9\pythonproject\.venv\lib\site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=6.2.0 in f:\data-collection-and-markup_9\pythonproject\.venv\lib\site-packages (from matplotlib) (10.4.0)
# Collecting pyparsing>=2.3.1 (from matplotlib)
#   Obtaining dependency information for pyparsing>=2.3.1 from https://files.pythonhosted.org/packages/e5/0c/0e3c05b1c87bb6a1c76d281b0f35e78d2d80ac91b5f8f524cebf77f51049/pyparsing-3.1.4-py3-none-any.whl.metadata
#   Downloading pyparsing-3.1.4-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: python-dateutil>=2.7 in f:\data-collection-and-markup_9\pythonproject\.venv\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: importlib-resources>=3.2.0 in f:\data-collection-and-markup_9\pythonproject\.venv\lib\site-packages (from matplotlib) (6.4.5)
# Requirement already satisfied: zipp>=3.1.0 in f:\data-collection-and-markup_9\pythonproject\.venv\lib\site-packages (from importlib-resources>=3.2.0->matplotlib) (3.20.2)
# Requirement already satisfied: six>=1.5 in f:\data-collection-and-markup_9\pythonproject\.venv\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Downloading matplotlib-3.7.5-cp38-cp38-win_amd64.whl (7.5 MB)
#    ---------------------------------------- 0.0/7.5 MB ? eta -:--:--
#    - -------------------------------------- 0.2/7.5 MB 3.6 MB/s eta 0:00:03
#    -- ------------------------------------- 0.5/7.5 MB 4.8 MB/s eta 0:00:02
#    ------ --------------------------------- 1.3/7.5 MB 6.7 MB/s eta 0:00:01
#    ---------- ----------------------------- 1.9/7.5 MB 7.2 MB/s eta 0:00:01
#    ---------- ----------------------------- 2.0/7.5 MB 7.3 MB/s eta 0:00:01
#    ---------------- ----------------------- 3.0/7.5 MB 8.1 MB/s eta 0:00:01
#    ---------------------- ----------------- 4.3/7.5 MB 8.6 MB/s eta 0:00:01
#    -------------------------- ------------- 4.9/7.5 MB 9.0 MB/s eta 0:00:01
#    -------------------------------- ------- 6.1/7.5 MB 9.0 MB/s eta 0:00:01
#    ------------------------------------- -- 7.1/7.5 MB 8.9 MB/s eta 0:00:01
#    ---------------------------------------  7.5/7.5 MB 8.9 MB/s eta 0:00:01
#    ---------------------------------------  7.5/7.5 MB 8.9 MB/s eta 0:00:01
#    ---------------------------------------  7.5/7.5 MB 8.9 MB/s eta 0:00:01
#    ---------------------------------------  7.5/7.5 MB 8.9 MB/s eta 0:00:01
#    ---------------------------------------  7.5/7.5 MB 8.9 MB/s eta 0:00:01
#    ---------------------------------------  7.5/7.5 MB 8.9 MB/s eta 0:00:01
#    ---------------------------------------  7.5/7.5 MB 8.9 MB/s eta 0:00:01
#    ---------------------------------------  7.5/7.5 MB 8.9 MB/s eta 0:00:01
#    ---------------------------------------  7.5/7.5 MB 8.9 MB/s eta 0:00:01
#    ---------------------------------------  7.5/7.5 MB 8.9 MB/s eta 0:00:01
#    ---------------------------------------  7.5/7.5 MB 8.9 MB/s eta 0:00:01
#    ---------------------------------------  7.5/7.5 MB 8.9 MB/s eta 0:00:01
#    ---------------------------------------  7.5/7.5 MB 8.9 MB/s eta 0:00:01
#    ---------------------------------------  7.5/7.5 MB 8.9 MB/s eta 0:00:01
#    ---------------------------------------  7.5/7.5 MB 8.9 MB/s eta 0:00:01
#    ---------------------------------------  7.5/7.5 MB 8.9 MB/s eta 0:00:01
#    ---------------------------------------  7.5/7.5 MB 8.9 MB/s eta 0:00:01
#    ---------------------------------------- 7.5/7.5 MB 4.2 MB/s eta 0:00:00
# Downloading contourpy-1.1.1-cp38-cp38-win_amd64.whl (477 kB)
#    ---------------------------------------- 0.0/477.9 kB ? eta -:--:--
#    --------------------------------------  471.0/477.9 kB 14.9 MB/s eta 0:00:01
#    --------------------------------------  471.0/477.9 kB 14.9 MB/s eta 0:00:01
#    ---------------------------------------- 477.9/477.9 kB 3.3 MB/s eta 0:00:00
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.54.1-cp38-cp38-win_amd64.whl (1.5 MB)
#    ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#    -------------------- ------------------- 0.8/1.5 MB 12.2 MB/s eta 0:00:01
#    -------------------------------------- - 1.5/1.5 MB 10.3 MB/s eta 0:00:01
#    ---------------------------------------  1.5/1.5 MB 10.7 MB/s eta 0:00:01
#    ---------------------------------------- 1.5/1.5 MB 6.1 MB/s eta 0:00:00
# Downloading kiwisolver-1.4.7-cp38-cp38-win_amd64.whl (55 kB)
#    ---------------------------------------- 0.0/55.8 kB ? eta -:--:--
#    ------------------------------------ --- 51.2/55.8 kB ? eta -:--:--
#    ------------------------------------ --- 51.2/55.8 kB ? eta -:--:--
#    ------------------------------------ --- 51.2/55.8 kB ? eta -:--:--
#    ------------------------------------ --- 51.2/55.8 kB ? eta -:--:--
#    ------------------------------------ --- 51.2/55.8 kB ? eta -:--:--
#    ------------------------------------ --- 51.2/55.8 kB ? eta -:--:--
#    ---------------------------------------- 55.8/55.8 kB 138.6 kB/s eta 0:00:00
# Downloading pyparsing-3.1.4-py3-none-any.whl (104 kB)
#    ---------------------------------------- 0.0/104.1 kB ? eta -:--:--
#    ---------------------------------------  102.4/104.1 kB 5.8 MB/s eta 0:00:01
#    ---------------------------------------  102.4/104.1 kB 5.8 MB/s eta 0:00:01
#    -------------------------------------- 104.1/104.1 kB 861.1 kB/s eta 0:00:00
# Installing collected packages: pyparsing, kiwisolver, fonttools, cycler, contourpy, matplotlib
# Successfully installed contourpy-1.1.1 cycler-0.12.1 fonttools-4.54.1 kiwisolver-1.4.7 matplotlib-3.7.5 pyparsing-3.1.4
# [notice] A new release of pip is available: 23.2.1 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Collecting wget
#   Using cached wget-3.2.zip (10 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Building wheels for collected packages: wget
#   Building wheel for wget (setup.py): started
#   Building wheel for wget (setup.py): finished with status 'done'
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9681 sha256=226be5f465ea23eada3ef57ce82e2b3c0c33eaf71ff58ae1fe7de96b54a76ca7
#   Stored in directory: c:\users\user\appdata\local\pip\cache\wheels\bd\a8\c3\3cf2c14a1837a4e04bd98631724e81f33f462d86a1d895fae0
# Successfully built wget
# Installing collected packages: wget
# Successfully installed wget-3.2
# [notice] A new release of pip is available: 23.2.1 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import nltk
# Загружаем предобученную модель токенизации текста
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('omw-1.4')
import csv
import os
import wget
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
import matplotlib
from sklearn.preprocessing import LabelEncoder
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
import numpy as np
from sklearn.metrics import f1_score
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\user\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\user\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\user\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!

# %%
# Загрузим датасет с новостями с lenta.ru (https://www.kaggle.com/datasets/yutkin/corpus-of-russian-news-articles-from-lenta)
data = pd.read_csv("lenta-ru-news.csv", engine='python', on_bad_lines="skip")

# %%
data
# Out:
#                                                 url  \
# 0        https://lenta.ru/news/1914/09/16/hungarnn/
# 1       https://lenta.ru/news/1914/09/16/lermontov/
# 2       https://lenta.ru/news/1914/09/17/nesteroff/
# 3        https://lenta.ru/news/1914/09/17/bulldogn/
# 4            https://lenta.ru/news/1914/09/18/zver/
# ...                                             ...
# 800970      https://lenta.ru/news/2019/12/14/shnur/
# 800971       https://lenta.ru/news/2019/12/14/dolg/
# 800972  https://lenta.ru/news/2019/12/14/dark_euro/
# 800973      https://lenta.ru/news/2019/12/14/meteo/
# 800974      https://lenta.ru/news/2019/12/14/olimp/
#
#                                                     title  \
# 0       1914. Русские войска вступили в пределы Венгрии
# 1       1914. Празднование столетия М.Ю. Лермонтова от...
# 2                                1914. Das ist Nesteroff!
# 3                         1914. Бульдог-гонец под Льежем
# 4                1914. Под Люблином пойман швабский зверь
# ...                                                   ...
# 800970          Шнуров раскритиковал Гагарину на «Голосе»
# 800971  В России предложили изменить правила взыскания...
# 800972          В России назвали «черную дату» для Европы
# 800973        Россиянам пообещали аномально теплую погоду
# 800974  В конкурсе прогнозов на АПЛ разыграют 100 тыся...
#
#                                                      text       topic  \
# 0       Бои у Сопоцкина и Друскеник закончились отступ...  Библиотека
# 1       Министерство народного просвещения, в виду про...  Библиотека
# 2       Штабс-капитан П. Н. Нестеров на днях, увидев в...  Библиотека
# 3       Фотограф-корреспондент Daily Mirror рассказыва...  Библиотека
# 4       Лица, приехавшие в Варшаву из Люблина, передаю...  Библиотека
# ...                                                   ...         ...
# 800970  Певец Сергей Шнуров раскритиковал свою коллегу...         NaN
# 800971  Министерство юстиции России предложило изменит...         NaN
# 800972  Испытание США ранее запрещенной Договором о ли...         NaN
# 800973  В ближайшие дни в европейской части России пог...         NaN
# 800974  Ведущие футбольные чемпионаты ушли на зимние к...         NaN
#
#                      tags        date
# 0          Первая мировая  1914/09/16
# 1          Первая мировая  1914/09/16
# 2          Первая мировая  1914/09/17
# 3          Первая мировая  1914/09/17
# 4          Первая мировая  1914/09/18
# ...                   ...         ...
# 800970         ТВ и радио  2019/12/14
# 800971                Все  2019/12/14
# 800972           Политика  2019/12/14
# 800973           Общество  2019/12/14
# 800974  Английский футбол  2019/12/14
#
# [800975 rows x 6 columns]

# %%
# Т.к. датасет очень большой, для дальнейшей работы выберем 1.5% от первоначального датасета
subset = data.sample(frac=0.015)

# %%
subset.to_csv("news_lenta-ru.csv", index=False)
# lenta-ru-news.csv

# %%
# Загрузим полученный датасет (1.5%) с новостями с lenta.ru
news = pd.read_csv("news_lenta-ru.csv", engine='python', on_bad_lines="skip")

# %%
news
# Out:
#                                                  url  \
# 0             https://lenta.ru/news/2008/09/03/mrap/
# 1          https://lenta.ru/news/2013/07/09/freddie/
# 2         https://lenta.ru/news/2017/08/17/achegone/
# 3       https://lenta.ru/world/2005/02/03/musharraf/
# 4          https://lenta.ru/news/2009/10/05/entropy/
# ...                                              ...
# 12010        https://lenta.ru/news/2016/05/20/draka/
# 12011     https://lenta.ru/news/2018/10/12/platform/
# 12012  https://lenta.ru/news/2019/03/12/rosneft_usa/
# 12013     https://lenta.ru/news/2017/04/07/pentagon/
# 12014        https://lenta.ru/news/2010/08/01/dutch/
#
#                                                    title  \
# 0      Испания закупила 100 бронемашин с противоминно...
# 1      Скульптуру гориллы в костюме Фредди Меркьюри в...
# 2           Умер создатель русского алфавита в интернете
# 3      Президент Пакистана продал права на свои мемуа...
# 4             Энтропия оказалась подвержена манипуляциям
# ...                                                  ...
# 12010  Неизвестные в масках и с битами устроили драку...
# 12011  Платформа «Северный полюс» будет наблюдать за ...
# 12012  «Роснефть» ответила госдепу США по поводу Вене...
# 12013  Пентагон рассказал о направлении предупреждени...
# 12014         Голландцы прекратили воевать в Афганистане
#
#                                                     text              topic  \
# 0      Компания General Dynamics заключила контракт с...    Наука и техника
# 1      Из центра английского Нориджа удалили стеклово...           Из жизни
# 2      Умер создатель кодировки KOI8-R для букв русск...     Интернет и СМИ
# 3      Президент Пакистана Первез Мушарраф продал в С...                Мир
# 4      Физикам удалось добиться перемещения энтропии ...    Наука и техника
# ...                                                  ...                ...
# 12010  Неизвестные устроили массовую драку на террито...             Россия
# 12011  В течение двух лет будет построена дрейфующая ...     69-я параллель
# 12012  В компании «Роснефть» крайне удивлены заявлени...                NaN
# 12013  США предупредили российских военных по установ...  Силовые структуры
# 12014  Голландские военнослужащие завершили участие в...                Мир
#
#                  tags        date
# 0                 Все  2008/09/03
# 1                Вещи  2013/07/09
# 2            Интернет  2017/08/17
# 3                 Все  2005/02/03
# 4                 Все  2009/10/05
# ...               ...         ...
# 12010    Происшествия  2016/05/20
# 12011         События  2018/10/12
# 12012  Деловой климат  2019/03/12
# 12013             NaN  2017/04/07
# 12014             Все  2010/08/01
#
# [12015 rows x 6 columns]

# %%
# Загрузка тонального словаря 
url = 'https://raw.githubusercontent.com/dkulagin/kartaslov/master/dataset/kartaslovsent/kartaslovsent.csv'
path = "kartaslovsent.csv"   # Датасет тонального словаря
if not os.path.isfile("kartaslovsent.csv"):
    # Загружаем данные
    wget.download(url, out=path)

# %%
df_tone_dictionary = pd.read_csv("kartaslovsent.csv", sep=';', on_bad_lines='skip')

# %%
df_tone_dictionary
# Out:
#                term   tag  value   pstv   ngtv   neut  dunno  \
# 0            абажур  NEUT   0.08  0.185  0.037  0.580  0.198
# 1         аббатство  NEUT   0.10  0.192  0.038  0.578  0.192
# 2      аббревиатура  NEUT   0.08  0.196  0.000  0.630  0.174
# 3             абзац  NEUT   0.00  0.137  0.000  0.706  0.157
# 4         абиссинец  NEUT   0.28  0.151  0.113  0.245  0.491
# ...             ...   ...    ...    ...    ...    ...    ...
# 46122       ёмкость  NEUT   0.00  0.167  0.000  0.690  0.143
# 46123        ёрзать  NGTV  -0.54  0.050  0.446  0.397  0.107
# 46124      ёрничать  NGTV  -0.79  0.078  0.529  0.236  0.157
# 46125           ёрш  NEUT   0.16  0.224  0.072  0.576  0.128
# 46126         ёршик  NEUT   0.00  0.152  0.043  0.718  0.087
#
#        pstvNgtvDisagreementRatio
# 0                           0.00
# 1                           0.00
# 2                           0.00
# 3                           0.00
# 4                           0.19
# ...                          ...
# 46122                       0.00
# 46123                       0.00
# 46124                       0.00
# 46125                       0.00
# 46126                       0.00
#
# [46127 rows x 8 columns]

# %%
# Присвоение метки настроения заголовкам новостей

# Перемешаем и разделим датафрейм на две части (1-разметка вручную, 2-разметка на основе правил)

# %%
# Перемешаем и разделим датафрем на 2 части
title_news_1, title_news_2 = train_test_split(news['title'], train_size=5, random_state=42)

# %%
# Преобразуем полученые датасеты в датафреймы Pandas
df_title_news_1 = pd.DataFrame(title_news_1)
df_title_news_2 = pd.DataFrame(title_news_2)

# %%
df_title_news_1.head()
# Out:
#                                                    title
# 11964  Футбольные фанаты избили корреспондента Russia...
# 5191   Греф проведет тотальную перепись всего малого ...
# 5390   Россия в 2010 году обеспечит работой 1,4 милли...
# 860    В Татарском проливе найдено тело восьмого рыба...
# 7270   Рестлер сломал ребра после прыжка на соперника...

# %%
df_title_news_2.head()
# Out:
#                                                   title
# 6134  Красный Крест обвиняет США в нарушении Женевск...
# 4671       В чеченском лесу блокировали группу боевиков
# 5721  Шинейд О’Коннор вновь рассказала о желании пок...
# 7220                Олимпийский огонь прибыл в Малайзию
# 429     Панталоны королевы Виктории продадут с аукциона

# %%
# Определение функций

# %%
import nltk
# Загружаем предобученную модель токенизации текста
nltk.download('punkt')
nltk.download('punkt_tab')
nltk.download('wordnet')
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\user\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\user\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\user\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\user\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# True

# %%
# Функция для присвоения метки настроения на основе наличия положительных или отрицательных слов
def get_sentiment(text, df_td=df_tone_dictionary): #   Функция вычисляет метрику настроения 
                                                   #   и возвращает оценку тональности: 
                                                   #  -0.35 (негативно) <= нейтрально >= (0.55) позитивно 
    # Токенизация текста на отдельные слова
    words = nltk.word_tokenize(text.lower())
    sum_value = 0  # Сумма всех значений весов найденных слов
    
    for word in words:
        if len(df_td[df_td.term == word]):
            df_filtered = df_td[df_td['term'] == word]
            value = df_filtered['value'].iloc[0]
            sum_value += value
 
    return sum_value

# %%
# Определение функции для присвоения метки настроения на основе оценки полярности настроения
def get_sentiment_label(score): #   Функция выводит метку настроения (негативный, позитивный или нейтральный)
                                #   и  возвращает оценку тональности
                                #   уровень метки настроения от -1 до 1,
    if score < -0.35:
        return 'negative'  
    elif score >= 0.55:
        return 'positive' 
    else:
        return 'neutral'

# %%
# %%time
get_sentiment('Бабушка приехала')
# Out:
# CPU times: total: 156 ms
# Wall time: 597 ms
# 0.97

# %%
get_sentiment('Ураганный ветер')
# Out:
# -0.7

# %%
get_sentiment('Всё в норме')
# Out:
# 0

# %%
get_sentiment_label(get_sentiment('Бабушка приехала'))
# Out:
# 'positive'

# %%
get_sentiment_label(get_sentiment('Ураганный ветер'))
# Out:
# 'negative'

# %%
get_sentiment_label(get_sentiment('Всё в норме'))
# Out:
# 'neutral'

# %%
# Присваиваем метки

# %%
# Присвоение меток настроения на основе правил

# %%
# %%time
# Применение функции к столбцу 'title' датасета для получения полярности настроения каждого заголовка новости
df_title_news_2['sentiment'] = df_title_news_2['title'].apply(get_sentiment)
# Применение функции к столбцу 'sentiment' датасета для присваения меток настроения
df_title_news_2['sentiment_label'] = df_title_news_2['sentiment'].apply(get_sentiment_label)
# Out:
# CPU times: total: 17min 11s
# Wall time: 21min 44s

# %%
df_title_news_2.head()
# Out:
#                                                   title  sentiment  \
# 6134  Красный Крест обвиняет США в нарушении Женевск...      -0.03
# 4671       В чеченском лесу блокировали группу боевиков       0.00
# 5721  Шинейд О’Коннор вновь рассказала о желании пок...      -0.54
# 7220                Олимпийский огонь прибыл в Малайзию       0.80
# 429     Панталоны королевы Виктории продадут с аукциона       0.09
#
#      sentiment_label
# 6134         neutral
# 4671         neutral
# 5721        negative
# 7220        positive
# 429          neutral

# %%
df_title_news_2.shape
# Out:
# (12010, 3)

# %%
# Присвоение меток настроения в label-studio

# %%
# Сохраним датафрем в CSV файл

# %%
df_title_news_1.to_csv('news_marking.csv', index=False)

# %%
# Запускаем label-studio

# %%
# !pip install label-studio
# Out:
# Requirement already satisfied: label-studio in f:\data-collection-and-markup_9\pythonproject\.venv\lib\site-packages (1.13.1)
# Requirement already satisfied: Django<3.3.0,>=3.2.24 in f:\data-collection-and-markup_9\pythonproject\.venv\lib\site-packages (from label-studio) (3.2.25)
# Requirement already satisfied: appdirs>=1.4.3 in f:\data-collection-and-markup_9\pythonproject\.venv\lib\site-packages (from label-studio) (1.4.4)
# Requirement already satisfied: attr==0.3.1 in f:\data-collection-and-markup_9\pythonproject\.venv\lib\site-packages (from label-studio) (0.3.1)
# Requirement already satisfied: attrs>=19.2.0 in f:\data-collection-and-markup_9\pythonproject\.venv\lib\site-packages (from label-studio) (24.2.0)
# Requirement already satisfied: azure-storage-blob>=12.6.0 in f:\data-collection-and-markup_9\pythonproject\.venv\lib\site-packages (from label-studio) (12.23.1)
# Requirement already satisfied: bleach<5.1.0,>=5.0.0 in f:\data-collection-and-markup_9\pythonproject\.venv\lib\site-packages (from label-studio) (5.0.1)
# Requirement already satisfied: boto<3.0.0,>=2.49.0 in f:\data-collection-and-markup_9\pythonproject\.venv\lib\site-packages (from label-studio) (2.49.0)
# Requirement already satisfied: boto3<2.0.0,>=1.28.58 in f:\data-collection-and-markup_9\pythonproject\.venv\lib\site-packages (from label-studio) (1.35.29)
# Requirement already satisfied: botocore<2.0.0,>=1.31.58 in f:\data-collection-and-markup_9\pythonproject\.venv\lib\site-packages (from label-studio) (1.35.29)
# Requirement already satisfied: boxing>=0.1.4 in f:\data-collection-and-markup_9\pythonproject\.venv\lib\site-packages (from label-studio) (0.1.4)
# Requirement already satisfied: colorama>=0.4.4 in f:\data-collection-and-markup_9\pythonproject\.venv\lib\site-packages (from label-studio) (0.4.6)
# Requirement already satisfied: defusedxml>=0.7.1 in f:\data-collection-and-markup_9\pythonproject\.venv\lib\site-packages (from label-studio) (0.7.1)
# Requirement already satisfied: django-annoying==0.10.6 in f:\data-collection-and-markup_9\pythonproject\.venv\lib\site-packages (from label-studio) (0.10.6)
# Requirement already satisfied: django-cors-headers==3.6.0 in f:\data-collection-and-markup_9\pythonproject\.venv\lib\site-packages (from label-studio) (3.6.0)
# Requirement already satisfied: django-csp==3.7 in f:\data-collection-and-markup_9\pythonproject\.venv\lib\site-packages (from label-studio) (3.7)
# Requirement already satisfied: django-debug-toolbar==3.2.1 in f:\data-collection-and-markup_9\pythonproject\.venv\lib\site-packages (from label-studio) (3.2.1)
# Requirement already satisfied: django-environ==0.10.0 in f:\data-collection-and-markup_9\pythonproject\.venv\lib\site-packages (from label-studio) (0.10.0)
# Requirement already satisfied: django-extensions==3.1.0 in f:\data-collection-and-markup_9\pythonproject\.venv\lib\site-packages (from label-studio) (3.1.0)
# Requirement already satisfied: django-filter==2.4.0 in f:\data-collection-and-markup_9\pythonproject\.venv\lib\site-packages (from label-studio) (2.4.0)
# Requirement already satisfied: django-model-utils==4.1.1 in f:\data-collection-and-markup_9\pythonproject\.venv\lib\site-packages (from label-studio) (4.1.1)
# Requirement already satisfied: django-ranged-fileresponse>=0.1.2 in f:\data-collection-and-markup_9\pythonproject\.venv\lib\site-packages (from label-studio) (0.1.2)
# Requirement already satisfied: django-rq==2.5.1 in f:\data-collection-and-markup_9\pythonproject\.venv\lib\site-packages (from label-studio) (2.5.1)
# Requirement already satisfied: django-storages==1.12.3 in f:\data-collection-and-markup_9\pythonproject\.venv\lib\site-packages (from label-studio) (1.12.3)
# Requirement already satisfied: django-user-agents==0.4.0 in f:\data-collection-and-markup_9\pythonproject\.venv\lib\site-packages (from label-studio) (0.4.0)
# Requirement already satisfied: djangorestframework==3.13.1 in f:\data-collection-and-markup_9\pythonproject\.venv\lib\site-packages (from label-studio) (3.13.1)
# Requirement already satisfied: drf-dynamic-fields==0.3.0 in f:\data-collection-and-markup_9\pythonproject\.venv\lib\site-packages (from label-studio) (0.3.0)
# Requirement already satisfied: drf-flex-fields==0.9.5 in f:\data-collection-and-markup_9\pythonproject\.venv\lib\site-packages (from label-studio) (0.9.5)
# Requirement already satisfied: drf-generators==0.3.0 in f:\data-collection-and-markup_9\pythonproject\.venv\lib\site-packages (from label-studio) (0.3.0)
# Requirement already satisfied: google-cloud-logging<4.0.0,>=3.10.0 in f:\data-collection-and-markup_9\pythonproject\.venv\lib\site-packages (from label-studio) (3.11.2)
# Requirement already satisfied: google-cloud-storage<3.0.0,>=2.13.0 in f:\data-collection-and-markup_9\pythonproject\.venv\lib\site-packages (from label-studio) (2.18.2)
# Requirement already satisfied: htmlmin==0.1.12 in f:\data-collection-and-markup_9\pythonproject\.venv\lib\site-packages (from label-studio) (0.1.12)
# Requirement already satisfied: humansignal-drf-yasg>=1.21.9 in f:\data-collection-and-markup_9\pythonproject\.venv\lib\site-packages (from label-studio) (1.21.9)
# Requirement already satisfied: jsonschema==3.2.0 in f:\data-collection-and-markup_9\pythonproject\.venv\lib\site-packages (from label-studio) (3.2.0)
# Requirement already satisfied: label-studio-sdk==1.0.5 in f:\data-collection-and-markup_9\pythonproject\.venv\lib\site-packages (from label-studio) (1.0.5)
# Requirement already satisfied: launchdarkly-server-sdk==8.2.1 in f:\data-collection-and-markup_9\pythonproject\.venv\lib\site-packages (from label-studio) (8.2.1)
# Requirement already satisfied: lockfile>=0.12.0 in f:\data-collection-and-markup_9\pythonproject\.venv\lib\site-packages (from label-studio) (0.12.2)
# Requirement already satisfied: lxml>=4.2.5 in f:\data-collection-and-markup_9\pythonproject\.venv\lib\site-packages (from label-studio) (5.3.0)
# Requirement already satisfied: numpy<2.0.0,>=1.24.3 in f:\data-collection-and-markup_9\pythonproject\.venv\lib\site-packages (from label-studio) (1.24.4)
# Requirement already satisfied: openai<2.0.0,>=1.10.0 in f:\data-collection-and-markup_9\pythonproject\.venv\lib\site-packages (from label-studio) (1.50.2)
# Requirement already satisfied: ordered-set==4.0.2 in f:\data-collection-and-markup_9\pythonproject\.venv\lib\site-packages (from label-studio) (4.0.2)
# Requirement already satisfied: pandas>=0.24.0 in f:\data-collection-and-markup_9\pythonproject\.venv\lib\site-packages (from label-studio) (2.0.3)
# Requirement already satisfied: psycopg2-binary==2.9.9 in f:\data-collection-and-markup_9\pythonproject\.venv\lib\site-packages (from label-studio) (2.9.9)
# Requirement already satisfied: pydantic>=2.7.3 in f:\data-collection-and-markup_9\pythonproject\.venv\lib\site-packages (from label-studio) (2.9.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in f:\data-collection-and-markup_9\pythonproject\.venv\lib\site-packages (from label-studio) (2.9.0.post0)
# Requirement already satisfied: python-json-logger==2.0.4 in f:\data-collection-and-markup_9\pythonproject\.venv\lib\site-packages (from label-studio) (2.0.4)
# Requirement already satisfied: pytz<2023.0,>=2022.1 in f:\data-collection-and-markup_9\pythonproject\.venv\lib\site-packages (from label-studio) (2022.7.1)
# Requirement already satisfied: pyyaml>=6.0.0 in f:\data-collection-and-markup_9\pythonproject\.venv\lib\site-packages (from label-studio) (6.0.2)
# Requirement already satisfied: redis<4.0,>=3.5 in f:\data-collection-and-markup_9\pythonproject\.venv\lib\site-packages (from label-studio) (3.5.3)
# Requirement already satisfied: requests<2.33.0,>=2.32.3 in f:\data-collection-and-markup_9\pythonproject\.venv\lib\site-packages (from label-studio) (2.32.3)
# Requirement already satisfied: rq==1.10.1 in f:\data-collection-and-markup_9\pythonproject\.venv\lib\site-packages (from label-studio) (1.10.1)
# Requirement already satisfied: rules==2.2 in f:\data-collection-and-markup_9\pythonproject\.venv\lib\site-packages (from label-studio) (2.2)
# Requirement already satisfied: sentry-sdk>=1.1.0 in f:\data-collection-and-markup_9\pythonproject\.venv\lib\site-packages (from label-studio) (2.14.0)
# Requirement already satisfied: ujson>=3.0.0 in f:\data-collection-and-markup_9\pythonproject\.venv\lib\site-packages (from label-studio) (5.10.0)
# Requirement already satisfied: urllib3<2.0.0,>=1.26.18 in f:\data-collection-and-markup_9\pythonproject\.venv\lib\site-packages (from label-studio) (1.26.20)
# Requirement already satisfied: wheel<=0.40.0,>=0.38.1 in f:\data-collection-and-markup_9\pythonproject\.venv\lib\site-packages (from label-studio) (0.40.0)
# Requirement already satisfied: xmljson==0.2.1 in f:\data-collection-and-markup_9\pythonproject\.venv\lib\site-packages (from label-studio) (0.2.1)
# Requirement already satisfied: six in f:\data-collection-and-markup_9\pythonproject\.venv\lib\site-packages (from django-annoying==0.10.6->label-studio) (1.16.0)
# Requirement already satisfied: sqlparse>=0.2.0 in f:\data-collection-and-markup_9\pythonproject\.venv\lib\site-packages (from django-debug-toolbar==3.2.1->label-studio) (0.5.1)
# Requirement already satisfied: user-agents in f:\data-collection-and-markup_9\pythonproject\.venv\lib\site-packages (from django-user-agents==0.4.0->label-studio) (2.2.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in f:\data-collection-and-markup_9\pythonproject\.venv\lib\site-packages (from jsonschema==3.2.0->label-studio) (0.20.0)
# Requirement already satisfied: setuptools in f:\data-collection-and-markup_9\pythonproject\.venv\lib\site-packages (from jsonschema==3.2.0->label-studio) (68.2.0)
# Requirement already satisfied: Pillow>=10.0.1 in f:\data-collection-and-markup_9\pythonproject\.venv\lib\site-packages (from label-studio-sdk==1.0.5->label-studio) (10.4.0)
# Requirement already satisfied: httpx>=0.21.2 in f:\data-collection-and-markup_9\pythonproject\.venv\lib\site-packages (from label-studio-sdk==1.0.5->label-studio) (0.27.2)
# Requirement already satisfied: ijson>=3.2.3 in f:\data-collection-and-markup_9\pythonproject\.venv\lib\site-packages (from label-studio-sdk==1.0.5->label-studio) (3.3.0)
# Requirement already satisfied: nltk<4.0.0,>=3.8.2 in f:\data-collection-and-markup_9\pythonproject\.venv\lib\site-packages (from label-studio-sdk==1.0.5->label-studio) (3.9.1)
# Requirement already satisfied: requests-mock==1.12.1 in f:\data-collection-and-markup_9\pythonproject\.venv\lib\site-packages (from label-studio-sdk==1.0.5->label-studio) (1.12.1)
# Requirement already satisfied: typing_extensions>=4.0.0 in f:\data-collection-and-markup_9\pythonproject\.venv\lib\site-packages (from label-studio-sdk==1.0.5->label-studio) (4.12.2)
# Requirement already satisfied: certifi>=2018.4.16 in f:\data-collection-and-markup_9\pythonproject\.venv\lib\site-packages (from launchdarkly-server-sdk==8.2.1->label-studio) (2024.8.30)
# Requirement already satisfied: expiringdict>=1.1.4 in f:\data-collection-and-markup_9\pythonproject\.venv\lib\site-packages (from launchdarkly-server-sdk==8.2.1->label-studio) (1.2.2)
# Requirement already satisfied: pyRFC3339>=1.0 in f:\data-collection-and-markup_9\pythonproject\.venv\lib\site-packages (from launchdarkly-server-sdk==8.2.1->label-studio) (1.1)
# Requirement already satisfied: semver>=2.10.2 in f:\data-collection-and-markup_9\pythonproject\.venv\lib\site-packages (from launchdarkly-server-sdk==8.2.1->label-studio) (3.0.2)
# Requirement already satisfied: click>=5.0.0 in f:\data-collection-and-markup_9\pythonproject\.venv\lib\site-packages (from rq==1.10.1->label-studio) (8.1.7)
# Requirement already satisfied: azure-core>=1.30.0 in f:\data-collection-and-markup_9\pythonproject\.venv\lib\site-packages (from azure-storage-blob>=12.6.0->label-studio) (1.31.0)
# Requirement already satisfied: cryptography>=2.1.4 in f:\data-collection-and-markup_9\pythonproject\.venv\lib\site-packages (from azure-storage-blob>=12.6.0->label-studio) (43.0.1)
# Requirement already satisfied: isodate>=0.6.1 in f:\data-collection-and-markup_9\pythonproject\.venv\lib\site-packages (from azure-storage-blob>=12.6.0->label-studio) (0.6.1)
# Requirement already satisfied: webencodings in f:\data-collection-and-markup_9\pythonproject\.venv\lib\site-packages (from bleach<5.1.0,>=5.0.0->label-studio) (0.5.1)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in f:\data-collection-and-markup_9\pythonproject\.venv\lib\site-packages (from boto3<2.0.0,>=1.28.58->label-studio) (1.0.1)
# Requirement already satisfied: s3transfer<0.11.0,>=0.10.0 in f:\data-collection-and-markup_9\pythonproject\.venv\lib\site-packages (from boto3<2.0.0,>=1.28.58->label-studio) (0.10.2)
# Requirement already satisfied: asgiref<4,>=3.3.2 in f:\data-collection-and-markup_9\pythonproject\.venv\lib\site-packages (from Django<3.3.0,>=3.2.24->label-studio) (3.8.1)
# Requirement already satisfied: google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1 in f:\data-collection-and-markup_9\pythonproject\.venv\lib\site-packages (from google-cloud-logging<4.0.0,>=3.10.0->label-studio) (2.20.0)
# Requirement already satisfied: google-auth!=2.24.0,!=2.25.0,<3.0.0dev,>=2.14.1 in f:\data-collection-and-markup_9\pythonproject\.venv\lib\site-packages (from google-cloud-logging<4.0.0,>=3.10.0->label-studio) (2.35.0)
# Requirement already satisfied: google-cloud-appengine-logging<2.0.0dev,>=0.1.3 in f:\data-collection-and-markup_9\pythonproject\.venv\lib\site-packages (from google-cloud-logging<4.0.0,>=3.10.0->label-studio) (1.4.5)
# Requirement already satisfied: google-cloud-audit-log<1.0.0dev,>=0.2.4 in f:\data-collection-and-markup_9\pythonproject\.venv\lib\site-packages (from google-cloud-logging<4.0.0,>=3.10.0->label-studio) (0.3.0)
# Requirement already satisfied: google-cloud-core<3.0.0dev,>=2.0.0 in f:\data-collection-and-markup_9\pythonproject\.venv\lib\site-packages (from google-cloud-logging<4.0.0,>=3.10.0->label-studio) (2.4.1)
# Requirement already satisfied: grpc-google-iam-v1<1.0.0dev,>=0.12.4 in f:\data-collection-and-markup_9\pythonproject\.venv\lib\site-packages (from google-cloud-logging<4.0.0,>=3.10.0->label-studio) (0.13.1)
# Requirement already satisfied: opentelemetry-api>=1.9.0 in f:\data-collection-and-markup_9\pythonproject\.venv\lib\site-packages (from google-cloud-logging<4.0.0,>=3.10.0->label-studio) (1.27.0)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.0 in f:\data-collection-and-markup_9\pythonproject\.venv\lib\site-packages (from google-cloud-logging<4.0.0,>=3.10.0->label-studio) (1.24.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.2 in f:\data-collection-and-markup_9\pythonproject\.venv\lib\site-packages (from google-cloud-logging<4.0.0,>=3.10.0->label-studio) (5.28.2)
# Requirement already satisfied: google-resumable-media>=2.7.2 in f:\data-collection-and-markup_9\pythonproject\.venv\lib\site-packages (from google-cloud-storage<3.0.0,>=2.13.0->label-studio) (2.7.2)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in f:\data-collection-and-markup_9\pythonproject\.venv\lib\site-packages (from google-cloud-storage<3.0.0,>=2.13.0->label-studio) (1.5.0)
# Requirement already satisfied: inflection>=0.3.1 in f:\data-collection-and-markup_9\pythonproject\.venv\lib\site-packages (from humansignal-drf-yasg>=1.21.9->label-studio) (0.5.1)
# Requirement already satisfied: packaging>=21.0 in f:\data-collection-and-markup_9\pythonproject\.venv\lib\site-packages (from humansignal-drf-yasg>=1.21.9->label-studio) (24.1)
# Requirement already satisfied: uritemplate>=3.0.0 in f:\data-collection-and-markup_9\pythonproject\.venv\lib\site-packages (from humansignal-drf-yasg>=1.21.9->label-studio) (4.1.1)
# Requirement already satisfied: anyio<5,>=3.5.0 in f:\data-collection-and-markup_9\pythonproject\.venv\lib\site-packages (from openai<2.0.0,>=1.10.0->label-studio) (4.5.0)
# Requirement already satisfied: distro<2,>=1.7.0 in f:\data-collection-and-markup_9\pythonproject\.venv\lib\site-packages (from openai<2.0.0,>=1.10.0->label-studio) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in f:\data-collection-and-markup_9\pythonproject\.venv\lib\site-packages (from openai<2.0.0,>=1.10.0->label-studio) (0.5.0)
# Requirement already satisfied: sniffio in f:\data-collection-and-markup_9\pythonproject\.venv\lib\site-packages (from openai<2.0.0,>=1.10.0->label-studio) (1.3.1)
# Requirement already satisfied: tqdm>4 in f:\data-collection-and-markup_9\pythonproject\.venv\lib\site-packages (from openai<2.0.0,>=1.10.0->label-studio) (4.66.5)
# Requirement already satisfied: tzdata>=2022.1 in f:\data-collection-and-markup_9\pythonproject\.venv\lib\site-packages (from pandas>=0.24.0->label-studio) (2024.2)
# Requirement already satisfied: annotated-types>=0.6.0 in f:\data-collection-and-markup_9\pythonproject\.venv\lib\site-packages (from pydantic>=2.7.3->label-studio) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in f:\data-collection-and-markup_9\pythonproject\.venv\lib\site-packages (from pydantic>=2.7.3->label-studio) (2.23.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in f:\data-collection-and-markup_9\pythonproject\.venv\lib\site-packages (from requests<2.33.0,>=2.32.3->label-studio) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in f:\data-collection-and-markup_9\pythonproject\.venv\lib\site-packages (from requests<2.33.0,>=2.32.3->label-studio) (3.10)
# Requirement already satisfied: exceptiongroup>=1.0.2 in f:\data-collection-and-markup_9\pythonproject\.venv\lib\site-packages (from anyio<5,>=3.5.0->openai<2.0.0,>=1.10.0->label-studio) (1.2.2)
# Requirement already satisfied: cffi>=1.12 in f:\data-collection-and-markup_9\pythonproject\.venv\lib\site-packages (from cryptography>=2.1.4->azure-storage-blob>=12.6.0->label-studio) (1.17.1)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in f:\data-collection-and-markup_9\pythonproject\.venv\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-cloud-logging<4.0.0,>=3.10.0->label-studio) (1.65.0)
# Requirement already satisfied: grpcio<2.0dev,>=1.33.2 in f:\data-collection-and-markup_9\pythonproject\.venv\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-cloud-logging<4.0.0,>=3.10.0->label-studio) (1.66.2)
# Requirement already satisfied: grpcio-status<2.0.dev0,>=1.33.2 in f:\data-collection-and-markup_9\pythonproject\.venv\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-cloud-logging<4.0.0,>=3.10.0->label-studio) (1.66.2)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in f:\data-collection-and-markup_9\pythonproject\.venv\lib\site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0dev,>=2.14.1->google-cloud-logging<4.0.0,>=3.10.0->label-studio) (5.5.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in f:\data-collection-and-markup_9\pythonproject\.venv\lib\site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0dev,>=2.14.1->google-cloud-logging<4.0.0,>=3.10.0->label-studio) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in f:\data-collection-and-markup_9\pythonproject\.venv\lib\site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0dev,>=2.14.1->google-cloud-logging<4.0.0,>=3.10.0->label-studio) (4.9)
# Requirement already satisfied: httpcore==1.* in f:\data-collection-and-markup_9\pythonproject\.venv\lib\site-packages (from httpx>=0.21.2->label-studio-sdk==1.0.5->label-studio) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in f:\data-collection-and-markup_9\pythonproject\.venv\lib\site-packages (from httpcore==1.*->httpx>=0.21.2->label-studio-sdk==1.0.5->label-studio) (0.14.0)
# Requirement already satisfied: joblib in f:\data-collection-and-markup_9\pythonproject\.venv\lib\site-packages (from nltk<4.0.0,>=3.8.2->label-studio-sdk==1.0.5->label-studio) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in f:\data-collection-and-markup_9\pythonproject\.venv\lib\site-packages (from nltk<4.0.0,>=3.8.2->label-studio-sdk==1.0.5->label-studio) (2024.9.11)
# Requirement already satisfied: deprecated>=1.2.6 in f:\data-collection-and-markup_9\pythonproject\.venv\lib\site-packages (from opentelemetry-api>=1.9.0->google-cloud-logging<4.0.0,>=3.10.0->label-studio) (1.2.14)
# Requirement already satisfied: importlib-metadata<=8.4.0,>=6.0 in f:\data-collection-and-markup_9\pythonproject\.venv\lib\site-packages (from opentelemetry-api>=1.9.0->google-cloud-logging<4.0.0,>=3.10.0->label-studio) (8.4.0)
# Requirement already satisfied: ua-parser>=0.10.0 in f:\data-collection-and-markup_9\pythonproject\.venv\lib\site-packages (from user-agents->django-user-agents==0.4.0->label-studio) (0.18.0)
# Requirement already satisfied: pycparser in f:\data-collection-and-markup_9\pythonproject\.venv\lib\site-packages (from cffi>=1.12->cryptography>=2.1.4->azure-storage-blob>=12.6.0->label-studio) (2.22)
# Requirement already satisfied: wrapt<2,>=1.10 in f:\data-collection-and-markup_9\pythonproject\.venv\lib\site-packages (from deprecated>=1.2.6->opentelemetry-api>=1.9.0->google-cloud-logging<4.0.0,>=3.10.0->label-studio) (1.16.0)
# Requirement already satisfied: zipp>=0.5 in f:\data-collection-and-markup_9\pythonproject\.venv\lib\site-packages (from importlib-metadata<=8.4.0,>=6.0->opentelemetry-api>=1.9.0->google-cloud-logging<4.0.0,>=3.10.0->label-studio) (3.20.2)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in f:\data-collection-and-markup_9\pythonproject\.venv\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth!=2.24.0,!=2.25.0,<3.0.0dev,>=2.14.1->google-cloud-logging<4.0.0,>=3.10.0->label-studio) (0.6.1)
# [notice] A new release of pip is available: 23.2.1 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !label-studio
# Out:
# ^C

# %%
# Экспортируем размеченный вручную CSV файл и зогружаем его в датафрейм

# %%
df_title_news_1 = pd.read_csv("project-1.csv", engine='python', on_bad_lines='skip')

# %%
df_title_news_1.head()
# Out:
#    annotation_id  annotator                   created_at  id  lead_time  \
# 0              1          1  2024-09-29T16:08:25.109948Z   1     18.735
# 1              2          1  2024-09-29T16:09:05.374325Z   2     13.131
# 2              3          1  2024-09-29T16:09:26.498394Z   3      6.770
# 3              4          1  2024-09-29T16:09:59.909605Z   4      7.341
# 4              5          1  2024-09-29T16:10:25.863949Z   5      4.486
#
#   sentiment                                              title  \
# 0  negative  Футбольные фанаты избили корреспондента Russia...
# 1   neutral  Греф проведет тотальную перепись всего малого ...
# 2  positive  Россия в 2010 году обеспечит работой 1,4 милли...
# 3   neutral  В Татарском проливе найдено тело восьмого рыба...
# 4  negative  Рестлер сломал ребра после прыжка на соперника...
#
#                     updated_at
# 0  2024-09-29T16:08:33.034497Z
# 1  2024-09-29T16:17:06.400265Z
# 2  2024-09-29T16:09:26.498394Z
# 3  2024-09-29T16:09:26.498394Z
# 4  2024-09-29T16:10:25.863949Z

# %%
# Оставим только нужные столбцы
df_title_news_1 = df_title_news_1[['title', 'sentiment']].rename(columns={'sentiment': 'sentiment_label'})

# %%
df_title_news_1.head()
# Out:
#                                                title sentiment_label
# 0  Футбольные фанаты избили корреспондента Russia...        negative
# 1  Греф проведет тотальную перепись всего малого ...         neutral
# 2  Россия в 2010 году обеспечит работой 1,4 милли...        positive
# 3  В Татарском проливе найдено тело восьмого рыба...         neutral
# 4  Рестлер сломал ребра после прыжка на соперника...        negative

# %%
# Объединение датафреймов

# %%
# Объеденим три датафрейма
df_title_news_concat = pd.concat([
    df_title_news_1,
    df_title_news_2,
], axis=0)

# %%
# Удалим лишний столбец
del df_title_news_concat['sentiment']

# %%
df_title_news_concat.head()
# Out:
#                                                title sentiment_label
# 0  Футбольные фанаты избили корреспондента Russia...        negative
# 1  Греф проведет тотальную перепись всего малого ...         neutral
# 2  Россия в 2010 году обеспечит работой 1,4 милли...        positive
# 3  В Татарском проливе найдено тело восьмого рыба...         neutral
# 4  Рестлер сломал ребра после прыжка на соперника...        negative

# %%
df_title_news_concat.shape
# Out:
# (12015, 2)

# %%
# Выведем график тональности заголовков новостей
df_title_news_concat['sentiment_label'].hist()
# Out:
# <Axes: >

# %%
# Статистика тональности заголоаков новостей
df_title_news_concat.groupby(['sentiment_label']).agg({'sentiment_label': ['count']})
# Out:
#                 sentiment_label
#                           count
# sentiment_label
# negative                   1168
# neutral                    8938
# positive                   1909

# %%
# Обучение модели

# %%
le = LabelEncoder()
# Преобразуем в датафрейме буквеное обозначение в цифровое
df_title_news_concat['sentiment_label'] = le.fit_transform(df_title_news_concat['sentiment_label'].astype(str))

# %%
df_title_news_concat.head()
# Out:
#                                                title  sentiment_label
# 0  Футбольные фанаты избили корреспондента Russia...                0
# 1  Греф проведет тотальную перепись всего малого ...                1
# 2  Россия в 2010 году обеспечит работой 1,4 милли...                2
# 3  В Татарском проливе найдено тело восьмого рыба...                1
# 4  Рестлер сломал ребра после прыжка на соперника...                0

# %%
# Перемешивание данных
df_title_news_concat = shuffle(df_title_news_concat)

# %%
# Разделение датасета на размеченную и неразмеченную выборки
labeled_title, unlabeled_title = train_test_split(df_title_news_concat, train_size=0.2, random_state=42)

# %%
labeled_title.head()
# Out:
#                                                   title  sentiment_label
# 1289  АСВ предрекло дальнейший рост ставок по банков...                2
# 6043                Ради Дерипаски пожертвуют пластиком                1
# 2202  В летевший из Москвы в Сеул российский A330 уд...                1
# 6024  На награждении чемпиона мира Кулижникова включ...                2
# 8889                       В честь Ющенко назвали улицу                2

# %%
unlabeled_title.head()
# Out:
#                                                    title  sentiment_label
# 5294   Украинский дезертир попросил политического убе...                0
# 11172  Слушатели "Эха Москвы" предпочли президента Хо...                1
# 4516   В ходе учений на северо-западе России солдат Н...                0
# 9245   Известный австралийский винодел взорвался на в...                2
# 8021       КамАЗ с хурмой и героином не доехал до России                1

# %%
# Определение функции для обучения модели логистической регрессии на размеченных данных
def train_model(labeled_title):
    # Векторизация текстовых данных с помощью TF-IDF
    vectorizer = TfidfVectorizer()
    X = vectorizer.fit_transform(labeled_title['title'])
    y = labeled_title['sentiment_label']

    # Обучение модели логистической регрессии на размеченных данных
    model = LogisticRegression()
    model.fit(X, y)

    return model, vectorizer

# %%
# Обучение начальной модели на небольшом наборе 
model, vectorizer = train_model(labeled_title)

# %%
# Использование исходной модели для прогнозирования настроения неразмеченных данных
X_unlabeled = vectorizer.transform(unlabeled_title['title'])
y_unlabeled_predicted = model.predict(X_unlabeled)

# %%
# Вычислить неопределенности или энтропии предсказаний
y_unlabeled_proba = model.predict_proba(X_unlabeled)
uncertainty = -(y_unlabeled_proba * np.log2(y_unlabeled_proba)).sum(axis=1)

# %%
# Выбор 100 наиболее неопределенных точек данных для маркировки человеком
labeled_title_new = unlabeled_title.iloc[uncertainty.argsort()[:100]]
unlabeled_title_new = unlabeled_title.iloc[uncertainty.argsort()[100:]]

# %%
labeled_title_new
# Out:
#                                                    title  sentiment_label
# 11516  У здания администрации президента РФ задержали...                1
# 243    Россия присоединилась к Монреальской конвенции...                1
# 11473   Россия столкнулась с перепроизводством картофеля                1
# 865          Россия испортила финансовый отчет Carlsberg                1
# 11018  Россия и Болгария договорятся о формате кирилл...                1
# ...                                                  ...              ...
# 10236  Авиаэксперт рассказал о потере сознания пилота...                1
# 11559  Двоих россиян в Гамбурге обвинили в избиении п...                1
# 7122                  Путин поведал о своей первой любви                1
# 8604   Львовского телефонного террориста задержали по...                1
# 7254   Американские военные: иракцы стреляют по нам и...                1
#
# [100 rows x 2 columns]

# %%
# Разметка новых точек данных и добавление их к размеченному множеству
labeled_title = pd.concat([labeled_title, labeled_title_new])

# %%
labeled_title.shape
# Out:
# (2503, 2)

# %%
unlabeled_title_new.shape
# Out:
# (9512, 2)

# %%
# Переобучение модели на расширенном маркированном множестве
model, vectorizer = train_model(labeled_title)

# %%
# Оценка обучения модели

# %%
# Загружаем тестовый датасет
title_test = pd.read_csv("test.csv", engine='python', on_bad_lines='skip')

# %%
# Преобразуем в датафрейме буквеное обозначение в цифровое
title_test['sentiment_label'] = le.fit_transform(title_test['sentiment_label'].astype(str))

# %%
title_test.head()
# Out:
#                                                title  sentiment_label
# 0  Вагоны московского метро будут складываться га...                1
# 1  В Чечню пытались проникнуть наемники из Пакистана                1
# 2   Таллинские заключенные предпочитают голод духоте                0
# 3  Адвокатам "Моста" не удалось дать отвод следов...                1
# 4            В поезде Донецк-Москва нашли взрывчатку                1

# %%
# Оценка модели на тестовом датасете
X_test = vectorizer.transform(title_test['title'])
y_test_predicted = model.predict(X_test)
f1 = f1_score(title_test['sentiment_label'], y_test_predicted, average='micro')

print(f1)
# Out:
# 0.8393200000000001

# %%
# Вывод:

# Выполнила разметку выбранного подмножества на основе правил, произвела разметку вручную другого подмножества. 
# Объединила эти две выборки в один дасет и произвела обучение модели. Эффективность обученной модели составила 84%. 
# Разметка на основе правил существенно экономит трудозатраты.
